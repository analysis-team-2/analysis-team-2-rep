# %% [markdown]
# ## 데이터 불러오기

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import dask.dataframe as dd
import vaex
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as spst
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import pickle
from sklearn.preprocessing import OneHotEncoder
import shap

# %%
card_data = '../data/five_city_data/merged_gyeonggi_day.csv'
flowpop_data = '../data/five_city_data/flowpop.csv'
commercial_area_ndc_data = '../data/five_city_data/updated_commerical_area_ndc.csv'
card_sample = '../data/gm_card.csv'

# %%
# card_df = dd.read_csv(card_sample,encoding='utf-8')

# %%
card_df = dd.read_csv(card_data,encoding='utf-8')
flowpop_df = dd.read_csv(flowpop_data,encoding='utf-8')
comm_df = dd.read_csv(commercial_area_ndc_data,encoding='utf-8')

# %% [markdown]
# ## 데이터 전처리

# %% [markdown]
# #### 카드 소비 데이터

# %%
card_df.head()
# Out:
#      ta_ymd  cty_rgn_no  admi_cty_no card_tpbuz_cd card_tpbuz_nm_1
# 0  20230101       41210     41210510           D05           소매/유통  \
# 1  20230101       41210     41210510           D11           소매/유통
# 2  20230101       41210     41210510           D11           소매/유통
# 3  20230101       41210     41210510           F02           생활서비스
# 4  20230101       41210     41210510           F02           생활서비스
#
#   card_tpbuz_nm_2  hour sex  age  day    amt  cnt
# 0           선물/완구     3   M    5    7  57576    2
# 1           종합소매점     3   F    7    7   8523    2
# 2           종합소매점     7   F    7    7   8023    2
# 3           미용서비스     3   M    4    7  28532    2
# 4           미용서비스     4   F    7    7  74074    2

# %%
flowpop_df.head()
# Out:
#      ETL_M   ADMI_CD  TIME_CD  M_10_CNT  F_10_CNT  M_20_CNT  F_20_CNT
# 0  2023-01  41111560        0   2858.84   2353.63   6248.39   4939.41  \
# 1  2023-01  41111560        1   3491.05   3021.34   7622.91   6183.19
# 2  2023-01  41111560        2   3433.43   3094.93   7369.46   5974.40
# 3  2023-01  41111560        3   3194.88   2955.40   7014.45   5704.24
# 4  2023-01  41111560        4   3003.63   2818.85   6716.24   5370.39
#
#    M_30_CNT  F_30_CNT  M_40_CNT  F_40_CNT  M_50_CNT  F_50_CNT  M_60_CNT
# 0   6684.28   4267.07   6304.54   5347.71   7495.55   5583.58   5411.89  \
# 1   7793.08   5365.17   7591.39   6765.04   9010.54   6842.45   6755.23
# 2   7510.31   5217.52   7282.29   6413.82   8717.53   6483.81   6631.32
# 3   7172.49   5138.34   6906.87   6334.15   8650.77   6395.10   6540.17
# 4   6980.61   4920.87   6908.53   6217.82   8911.40   6465.25   6940.02
#
#    F_60_CNT  M_70_CNT  F_70_CNT
# 0   4223.19   1086.22   1165.65
# 1   5363.00   1369.42   1499.24
# 2   5241.16   1303.01   1483.83
# 3   5316.28   1333.23   1501.99
# 4   5642.58   1519.33   1577.52

# %%
comm_df.head()
# Out:
#       행정동코드  기준분기  운영점포평균영업기간  폐업점포평균영업기간 상권변동지표구분 상권변동지표구분명
# 0  41111560     1        99.9        46.4       HL      상권축소
# 1  41111566     1        83.5        43.2       LL      다이나믹
# 2  41111571     1        97.9        38.1       HL      상권축소
# 3  41111572     1        92.9        58.5       HH        정체
# 4  41111573     1        93.1        70.1       HH        정체

# %% [markdown]
# ## 데이터 결합

# %% [markdown]
# ### 월 별 데이터로 통합, 유동인구와 상권변화지표도 통합

# %%
# 해당일, 해당동의 해당 업종의 특정시간에 매출과 매출건수 총액
card_df2 = card_df.groupby(["ta_ymd", "admi_cty_no", "card_tpbuz_cd"]).agg({"amt": "sum", "cnt":"sum"}).reset_index()

# %%
card_df2.head()
# Out:
#      ta_ymd  admi_cty_no card_tpbuz_cd     amt  cnt
# 0  20230101     41210510           D05   57576    2
# 1  20230101     41210510           D11   16546    4
# 2  20230101     41210510           F02  313388   16
# 3  20230101     41210510           Q01   69266    1
# 4  20230101     41210510           Q15   78222    6

# %%
card_df2['ta_ymd'] = card_df2['ta_ymd'].astype(str)

# %%
card_df2['ta_ymd'] = card_df2['ta_ymd'].str.slice(0, 6)

# %%
card_df2.head()
# Out:
#    ta_ymd  admi_cty_no card_tpbuz_cd     amt  cnt
# 0  202301     41210510           D05   57576    2
# 1  202301     41210510           D11   16546    4
# 2  202301     41210510           F02  313388   16
# 3  202301     41210510           Q01   69266    1
# 4  202301     41210510           Q15   78222    6

# %%
# 월별 행정구별, 업종별, amt 및 cnt 평균
grouped_df = card_df2.groupby(["ta_ymd", "admi_cty_no", "card_tpbuz_cd"]).agg({"amt": "sum", "cnt": "sum"}).reset_index()
grouped_df.head()
# Out:
#    ta_ymd  admi_cty_no card_tpbuz_cd       amt  cnt
# 0  202301     41210510           D05    633562   28
# 1  202301     41210510           D11    171040   28
# 2  202301     41210510           F02  12060758  375
# 3  202301     41210510           Q01   1818710    9
# 4  202301     41210510           Q15   2167723   87

# %%
# join을 위한 데이터 통일
flowpop_df['ETL_M'] = flowpop_df['ETL_M'].str.replace('-', '')
# 총 유동인구 계산
cnt_columns = flowpop_df.loc[:, 'M_10_CNT':'F_70_CNT'].columns
flowpop_df['TOTAL_POPULATION'] = flowpop_df[cnt_columns].sum(axis=1)
# 해당 월에 해당 동에 해당 시간에 방문한 유동인구수 평균
flowpop_df_temp = flowpop_df.groupby(["ETL_M", "ADMI_CD","TIME_CD"]).agg({"TOTAL_POPULATION": "mean"}).reset_index()
# 해당 월에 해당 동에 방문한 유동인구 평균 총합
flow_g_df = flowpop_df_temp.groupby(["ETL_M", "ADMI_CD"]).agg({"TOTAL_POPULATION": "sum"}).reset_index()

# %%
flow_g_df.head()
# Out:
#     ETL_M   ADMI_CD  TOTAL_POPULATION
# 0  202301  41111560        2968697.82
# 1  202301  41111566        5438074.73
# 2  202301  41111571        2764829.73
# 3  202301  41111572        3664691.19
# 4  202301  41111573        5278122.27

# %%
# 데이터 결합
merged_df = dd.merge(grouped_df, flow_g_df, how='inner', left_on=['ta_ymd', 'admi_cty_no'], right_on=['ETL_M', 'ADMI_CD'])

# %%
merged_df.head()
# Out:
#    ta_ymd  admi_cty_no card_tpbuz_cd       amt  cnt   ETL_M   ADMI_CD
# 0  202301     41210510           D05    633562   28  202301  41210510  \
# 1  202301     41210510           D11    171040   28  202301  41210510
# 2  202301     41210510           F02  12060758  375  202301  41210510
# 3  202301     41210510           Q01   1818710    9  202301  41210510
# 4  202301     41210510           Q15   2167723   87  202301  41210510
#
#    TOTAL_POPULATION
# 0          13850.98
# 1          13850.98
# 2          13850.98
# 3          13850.98
# 4          13850.98

# %%
# 기준분기 생성 함수
def get_quarter(month):
    if month in [1, 2, 3]:
        return 1
    elif month in [4, 5, 6]:
        return 2
    elif month in [7, 8, 9]:
        return 3
    elif month in [10, 11, 12]:
        return 4

# merged_df에서 기준분기 생성
merged_df['year'] = merged_df['ta_ymd'].astype(str).str[:4].astype(int)
merged_df['month'] = merged_df['ta_ymd'].astype(str).str[4:6].astype(int)
merged_df['기준분기'] = merged_df['month'].apply(get_quarter)

# comm_df에서 기준분기와 매칭될 수 있도록 연도를 추가
comm_df['year'] = 2023
# Out:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=('month', 'int64'))

# %%
merged_df.head()
# Out:
#    ta_ymd  admi_cty_no card_tpbuz_cd       amt  cnt   ETL_M   ADMI_CD
# 0  202301     41210510           D05    633562   28  202301  41210510  \
# 1  202301     41210510           D11    171040   28  202301  41210510
# 2  202301     41210510           F02  12060758  375  202301  41210510
# 3  202301     41210510           Q01   1818710    9  202301  41210510
# 4  202301     41210510           Q15   2167723   87  202301  41210510
#
#    TOTAL_POPULATION  year  month  기준분기
# 0          13850.98  2023      1     1
# 1          13850.98  2023      1     1
# 2          13850.98  2023      1     1
# 3          13850.98  2023      1     1
# 4          13850.98  2023      1     1

# %%
comm_df.head()
# Out:
#       행정동코드  기준분기  운영점포평균영업기간  폐업점포평균영업기간 상권변동지표구분 상권변동지표구분명  year
# 0  41111560     1        99.9        46.4       HL      상권축소  2023
# 1  41111566     1        83.5        43.2       LL      다이나믹  2023
# 2  41111571     1        97.9        38.1       HL      상권축소  2023
# 3  41111572     1        92.9        58.5       HH        정체  2023
# 4  41111573     1        93.1        70.1       HH        정체  2023

# %%
# comm_df와 merged_df 병합
merged_result = dd.merge(merged_df, comm_df, left_on=['admi_cty_no', '기준분기', 'year'], right_on=['행정동코드', '기준분기', 'year'], how='left')

# 병합 결과에서 필요없는 열 제거 (예: '행정동코드')
merged_result = merged_result.drop(columns=['행정동코드'])

# 병합 결과 출력
merged_result.head()
# Out:
#    ta_ymd  admi_cty_no card_tpbuz_cd       amt  cnt   ETL_M   ADMI_CD
# 0  202301     41210510           D05    633562   28  202301  41210510  \
# 1  202301     41210510           D11    171040   28  202301  41210510
# 2  202301     41210510           F02  12060758  375  202301  41210510
# 3  202301     41210510           Q01   1818710    9  202301  41210510
# 4  202301     41210510           Q15   2167723   87  202301  41210510
#
#    TOTAL_POPULATION  year  month  기준분기  운영점포평균영업기간  폐업점포평균영업기간 상권변동지표구분
# 0          13850.98  2023      1     1       188.5       358.0       HH  \
# 1          13850.98  2023      1     1       188.5       358.0       HH
# 2          13850.98  2023      1     1       188.5       358.0       HH
# 3          13850.98  2023      1     1       188.5       358.0       HH
# 4          13850.98  2023      1     1       188.5       358.0       HH
#
#   상권변동지표구분명
# 0        정체
# 1        정체
# 2        정체
# 3        정체
# 4        정체

# %%
# 해당 행정동의 상권 지표를 결합
#merged_df2 = dd.merge(merged_df, comm_df, how='inner', left_on=['admi_cty_no'], right_on=['행정동코드'])

# %%
merged_result.columns
# Out:
# Index(['ta_ymd', 'admi_cty_no', 'card_tpbuz_cd', 'amt', 'cnt', 'ETL_M',
#        'ADMI_CD', 'TOTAL_POPULATION', 'year', 'month', '기준분기', '운영점포평균영업기간',
#        '폐업점포평균영업기간', '상권변동지표구분', '상권변동지표구분명'],
#       dtype='object')

# %%
columns_to_drop = ['ta_ymd','ETL_M', 'ADMI_CD', 'year','기준분기',
                   '상권변동지표구분명','month']
merged_df2 = merged_result.drop(columns=columns_to_drop)

# %%
merged_df2.head(10)
# Out:
#    ta_ymd  admi_cty_no card_tpbuz_cd       amt  cnt  TOTAL_POPULATION
# 0  202301     41210510           D05    633562   28          13850.98  \
# 1  202301     41210510           D11    171040   28          13850.98
# 2  202301     41210510           F02  12060758  375          13850.98
# 3  202301     41210510           Q01   1818710    9          13850.98
# 4  202301     41210510           Q15   2167723   87          13850.98
# 5  202301     41210510           Q02   2805688   71          13850.98
# 6  202301     41210510           Q06    375375   57          13850.98
# 7  202301     41210510           D08   2434495  161          13850.98
# 8  202301     41210510           D10   2344282   24          13850.98
# 9  202301     41210510           F10   5147052   11          13850.98
#
#    운영점포평균영업기간  폐업점포평균영업기간 상권변동지표구분
# 0       188.5       358.0       HH
# 1       188.5       358.0       HH
# 2       188.5       358.0       HH
# 3       188.5       358.0       HH
# 4       188.5       358.0       HH
# 5       188.5       358.0       HH
# 6       188.5       358.0       HH
# 7       188.5       358.0       HH
# 8       188.5       358.0       HH
# 9       188.5       358.0       HH

# %%
# 505027 rows
len(merged_df2)
# Out:
# 134360

# %%
merged_df2.head()
# Out:
#    admi_cty_no card_tpbuz_cd       amt  cnt  TOTAL_POPULATION  운영점포평균영업기간
# 0     41210510           D05    633562   28          13850.98       188.5  \
# 1     41210510           D11    171040   28          13850.98       188.5
# 2     41210510           F02  12060758  375          13850.98       188.5
# 3     41210510           Q01   1818710    9          13850.98       188.5
# 4     41210510           Q15   2167723   87          13850.98       188.5
#
#    폐업점포평균영업기간 상권변동지표구분
# 0       358.0       HH
# 1       358.0       HH
# 2       358.0       HH
# 3       358.0       HH
# 4       358.0       HH

# %% [markdown]
# ## One hot encoding, train-test split

# %%
merged_df2 = merged_df2.compute()

# %%
merged_df2 = TabularDataset(merged_df2)
# merged_df2 = merged_df2.drop(columns=['ta_ymd'])

# %%
merged_df2.head()
# Out:
#    admi_cty_no card_tpbuz_cd       amt  cnt  TOTAL_POPULATION  운영점포평균영업기간
# 0     41210510           D05    633562   28          13850.98       188.5  \
# 1     41210510           D11    171040   28          13850.98       188.5
# 2     41210510           F02  12060758  375          13850.98       188.5
# 3     41210510           Q01   1818710    9          13850.98       188.5
# 4     41210510           Q15   2167723   87          13850.98       188.5
#
#    폐업점포평균영업기간 상권변동지표구분
# 0       358.0       HH
# 1       358.0       HH
# 2       358.0       HH
# 3       358.0       HH
# 4       358.0       HH

# %%
merged_df2 = merged_df2.dropna(subset=['상권변동지표구분'])

# %%
len(merged_df2)
# Out:
# 75354

# %% [markdown]
# #### 인코딩시 사용되는 속성 저장

# %%
# train_df, test_df = train_test_split(train_data_encoded, test_size=0.2, random_state=42)
train_df, test_df = train_test_split(merged_df2, test_size=0.2, random_state=42)

# %% [markdown]
# ## 모델 학습1

# %%
# Autogluon TabularPredictor 사용
predictor = TabularPredictor(
    label='amt',  # 예측할 타겟 컬럼 설정
    eval_metric='mean_absolute_error'  # 평가 지표 설정 
)

# 모델 훈련
predictor.fit(
    train_data=train_df,
    presets='good_quality_faster_inference_only_refit',  # 가벼운 모델 설정
    time_limit=3600  # 학습 시간 2시간으로 제한 (1800초)
)

# 예측 수행
predictions = predictor.predict(test_df)

# 예측 결과 및 실제 값 비교
print("Predictions:\n", predictions)
print("Actual:\n", test_df['amt'])
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20240718_004914"
# Preset alias specified: 'good_quality_faster_inference_only_refit' maps to 'good_quality'.
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.8.18
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          12
# Memory Avail:       16.39 GB / 31.69 GB (51.7%)
# Disk Space Avail:   517.19 GB / 930.86 GB (55.6%)
# ===================================================
# Presets specified: ['good_quality_faster_inference_only_refit']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Note: `save_bag_folds=False`! This will greatly reduce peak disk usage during fit (by ~8x), but runs the risk of an out-of-memory error during model refit if memory is small relative to the data size.
# 	You can avoid this risk by setting `save_bag_folds=True`.
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-07-18 09:49:25,772	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "AutogluonModels\ag-20240718_004914\ds_sub_fit\sub_fit_ho"
# (_dystack pid=19824) Running DyStack sub-fit ...
# (_dystack pid=19824) Beginning AutoGluon training ... Time limit = 885s
# (_dystack pid=19824) AutoGluon will save models to "AutogluonModels\ag-20240718_004914\ds_sub_fit\sub_fit_ho"
# (_dystack pid=19824) Train Data Rows:    53584
# (_dystack pid=19824) Train Data Columns: 7
# (_dystack pid=19824) Label Column:       amt
# (_dystack pid=19824) Problem Type:       regression
# (_dystack pid=19824) Preprocessing data ...
# (_dystack pid=19824) Using Feature Generators to preprocess the data ...
# (_dystack pid=19824) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=19824) 	Available Memory:                    15928.61 MB
# (_dystack pid=19824) 	Train Data (Original)  Memory Usage: 8.13 MB (0.1% of available memory)
# (_dystack pid=19824) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=19824) 	Stage 1 Generators:
# (_dystack pid=19824) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=19824) 	Stage 2 Generators:
# (_dystack pid=19824) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=19824) 	Stage 3 Generators:
# (_dystack pid=19824) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=19824) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=19824) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=19824) 	Stage 4 Generators:
# (_dystack pid=19824) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=19824) 	Stage 5 Generators:
# (_dystack pid=19824) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=19824) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=19824) 		('float', [])  : 3 | ['TOTAL_POPULATION', '운영점포평균영업기간', '폐업점포평균영업기간']
# (_dystack pid=19824) 		('int', [])    : 2 | ['admi_cty_no', 'cnt']
# (_dystack pid=19824) 		('object', []) : 2 | ['card_tpbuz_cd', '상권변동지표구분']
# (_dystack pid=19824) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=19824) 		('category', []) : 2 | ['card_tpbuz_cd', '상권변동지표구분']
# (_dystack pid=19824) 		('float', [])    : 3 | ['TOTAL_POPULATION', '운영점포평균영업기간', '폐업점포평균영업기간']
# (_dystack pid=19824) 		('int', [])      : 2 | ['admi_cty_no', 'cnt']
# (_dystack pid=19824) 	0.2s = Fit runtime
# (_dystack pid=19824) 	7 features in original data used to generate 7 features in processed data.
# (_dystack pid=19824) 	Train Data (Processed) Memory Usage: 2.15 MB (0.0% of available memory)
# (_dystack pid=19824) Data preprocessing and feature engineering runtime = 0.19s ...
# (_dystack pid=19824) AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# (_dystack pid=19824) 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# (_dystack pid=19824) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=19824) User-specified model hyperparameters to be fit:
# (_dystack pid=19824) {
# (_dystack pid=19824) 	'NN_TORCH': {},
# (_dystack pid=19824) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=19824) 	'CAT': {},
# (_dystack pid=19824) 	'XGB': {},
# (_dystack pid=19824) 	'FASTAI': {},
# (_dystack pid=19824) 	'RF': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=19824) 	'XT': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=19824) }
# (_dystack pid=19824) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=19824) Fitting 9 L1 models ...
# (_dystack pid=19824) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 589.86s of the 885.01s of remaining time.
# (_dystack pid=19824) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# (_ray_fit pid=30948) [1000]	valid_set's l1: 1.77673e+08
# (_ray_fit pid=31020) [3000]	valid_set's l1: 1.64323e+08 [repeated 10x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=31020) [5000]	valid_set's l1: 1.48488e+08 [repeated 10x across cluster]
# (_ray_fit pid=22288) [7000]	valid_set's l1: 1.2353e+08 [repeated 10x across cluster]
# (_ray_fit pid=31020) [9000]	valid_set's l1: 1.32299e+08 [repeated 10x across cluster]
# (_dystack pid=19824) 	-148327996.0663	 = Validation score   (-mean_absolute_error)
# (_dystack pid=19824) 	35.66s	 = Training   runtime
# (_dystack pid=19824) 	114.95s	 = Validation runtime
# (_dystack pid=19824) Fitting model: LightGBM_BAG_L1 ... Training model for up to 525.05s of the 820.2s of remaining time.
# (_dystack pid=19824) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.12%)
# (_ray_fit pid=12876) [1000]	valid_set's l1: 1.03295e+08 [repeated 10x across cluster]
# (_ray_fit pid=2136) [3000]	valid_set's l1: 8.86413e+07 [repeated 16x across cluster]
# (_ray_fit pid=2136) [5000]	valid_set's l1: 8.42949e+07 [repeated 16x across cluster]
# (_ray_fit pid=12876) [7000]	valid_set's l1: 8.68051e+07 [repeated 16x across cluster]
# (_ray_fit pid=12876) [9000]	valid_set's l1: 8.54069e+07 [repeated 16x across cluster]
# (_dystack pid=19824) 	-89029170.0451	 = Validation score   (-mean_absolute_error)
# (_dystack pid=19824) 	41.48s	 = Training   runtime
# (_dystack pid=19824) 	206.73s	 = Validation runtime
# (_dystack pid=19824) Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 453.08s of the 748.23s of remaining time.
# (_dystack pid=19824) 	-94406746.9461	 = Validation score   (-mean_absolute_error)
# (_dystack pid=19824) 	14.19s	 = Training   runtime
# (_dystack pid=19824) 	1.2s	 = Validation runtime
# (_dystack pid=19824) Fitting model: CatBoost_BAG_L1 ... Training model for up to 437.39s of the 732.55s of remaining time.
# (_dystack pid=19824) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# (_dystack pid=19824) 	-140528123.4983	 = Validation score   (-mean_absolute_error)
# (_dystack pid=19824) 	350.77s	 = Training   runtime
# (_dystack pid=19824) 	0.25s	 = Validation runtime
# (_dystack pid=19824) Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 81.96s of the 377.11s of remaining time.
# (_dystack pid=19824) 	-126430792.885	 = Validation score   (-mean_absolute_error)
# (_dystack pid=19824) 	2.57s	 = Training   runtime
# (_dystack pid=19824) 	0.94s	 = Validation runtime
# (_dystack pid=19824) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 78.22s of the 373.37s of remaining time.
# (_dystack pid=19824) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.18%)
# (_dystack pid=19824) 	-230211977.597	 = Validation score   (-mean_absolute_error)
# (_dystack pid=19824) 	62.89s	 = Training   runtime
# (_dystack pid=19824) 	1.12s	 = Validation runtime
# (_dystack pid=19824) Fitting model: XGBoost_BAG_L1 ... Training model for up to 10.67s of the 305.82s of remaining time.
# (_dystack pid=19824) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.18%)
# (_dystack pid=19824) 	-104685299.3061	 = Validation score   (-mean_absolute_error)
# (_dystack pid=19824) 	8.87s	 = Training   runtime
# (_dystack pid=19824) 	1.01s	 = Validation runtime
# (_dystack pid=19824) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 291.88s of remaining time.
# (_dystack pid=19824) 	Ensemble Weights: {'LightGBM_BAG_L1': 0.545, 'RandomForestMSE_BAG_L1': 0.273, 'XGBoost_BAG_L1': 0.136, 'LightGBMXT_BAG_L1': 0.045}
# (_dystack pid=19824) 	-80321290.3734	 = Validation score   (-mean_absolute_error)
# (_dystack pid=19824) 	0.23s	 = Training   runtime
# (_dystack pid=19824) 	0.0s	 = Validation runtime
# (_dystack pid=19824) Fitting 9 L2 models ...
# (_dystack pid=19824) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 291.6s of the 291.58s of remaining time.
# (_dystack pid=19824) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.18%)
# (_ray_fit pid=30124) [1000]	valid_set's l1: 1.30047e+08 [repeated 16x across cluster]
# (_ray_fit pid=25728) [2000]	valid_set's l1: 1.12561e+08 [repeated 11x across cluster]
# (_ray_fit pid=34764) [4000]	valid_set's l1: 1.01327e+08 [repeated 7x across cluster]
# (_ray_fit pid=25728) [5000]	valid_set's l1: 1.04506e+08 [repeated 11x across cluster]
# (_ray_fit pid=30124) [7000]	valid_set's l1: 1.12201e+08 [repeated 7x across cluster]
# (_ray_fit pid=25728) [8000]	valid_set's l1: 1.01497e+08 [repeated 11x across cluster]
# (_ray_fit pid=30124) [10000]	valid_set's l1: 1.10414e+08 [repeated 7x across cluster]
# (_dystack pid=19824) 	-107340779.1124	 = Validation score   (-mean_absolute_error)
# (_dystack pid=19824) 	51.6s	 = Training   runtime
# (_dystack pid=19824) 	146.03s	 = Validation runtime
# (_dystack pid=19824) Fitting model: LightGBM_BAG_L2 ... Training model for up to 212.37s of the 212.35s of remaining time.
# (_dystack pid=19824) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.18%)
# (_ray_fit pid=31548) [1000]	valid_set's l1: 7.9261e+07 [repeated 6x across cluster]
# (_ray_fit pid=21600) [3000]	valid_set's l1: 9.6304e+07 [repeated 5x across cluster]
# (_ray_fit pid=21600) [5000]	valid_set's l1: 9.54903e+07 [repeated 4x across cluster]
# (_ray_fit pid=21600) [7000]	valid_set's l1: 9.48384e+07 [repeated 4x across cluster]
# (_ray_fit pid=21600) [9000]	valid_set's l1: 9.43968e+07 [repeated 4x across cluster]
# (_dystack pid=19824) 	-87454947.1789	 = Validation score   (-mean_absolute_error)
# (_dystack pid=19824) 	36.8s	 = Training   runtime
# (_dystack pid=19824) 	24.14s	 = Validation runtime
# (_dystack pid=19824) Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 159.61s of the 159.59s of remaining time.
# (_dystack pid=19824) 	-60962656.891	 = Validation score   (-mean_absolute_error)
# (_dystack pid=19824) 	67.7s	 = Training   runtime
# (_dystack pid=19824) 	1.32s	 = Validation runtime
# (_dystack pid=19824) Fitting model: CatBoost_BAG_L2 ... Training model for up to 90.38s of the 90.36s of remaining time.
# (_dystack pid=19824) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.20%)
# (_dystack pid=19824) 	-79065483.5978	 = Validation score   (-mean_absolute_error)
# (_dystack pid=19824) 	72.4s	 = Training   runtime
# (_dystack pid=19824) 	0.1s	 = Validation runtime
# (_dystack pid=19824) Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 12.98s of the 12.97s of remaining time.
# (_dystack pid=19824) 	-63744569.6252	 = Validation score   (-mean_absolute_error)
# (_dystack pid=19824) 	3.32s	 = Training   runtime
# (_dystack pid=19824) 	0.99s	 = Validation runtime
# (_dystack pid=19824) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 8.45s of remaining time.
# (_dystack pid=19824) 	Ensemble Weights: {'RandomForestMSE_BAG_L2': 0.76, 'ExtraTreesMSE_BAG_L2': 0.2, 'LightGBM_BAG_L2': 0.04}
# (_dystack pid=19824) 	-60510433.9449	 = Validation score   (-mean_absolute_error)
# (_dystack pid=19824) 	0.17s	 = Training   runtime
# (_dystack pid=19824) 	0.0s	 = Validation runtime
# (_dystack pid=19824) AutoGluon training complete, total runtime = 876.94s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 19.2 rows/s (6698 batch size)
# (_dystack pid=19824) Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# (_dystack pid=19824) Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# (_dystack pid=19824) 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# (_dystack pid=19824) 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# (_dystack pid=19824) 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# (_dystack pid=19824) Fitting 1 L1 models ...
# (_dystack pid=19824) Fitting model: LightGBMXT_BAG_L1_FULL ...
# (_dystack pid=19824) 	10.1s	 = Training   runtime
# (_dystack pid=19824) Fitting 1 L1 models ...
# (_dystack pid=19824) Fitting model: LightGBM_BAG_L1_FULL ...
# (_dystack pid=19824) 	11.58s	 = Training   runtime
# (_dystack pid=19824) Fitting model: RandomForestMSE_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=19824) 	14.19s	 = Training   runtime
# (_dystack pid=19824) 	1.2s	 = Validation runtime
# (_dystack pid=19824) Fitting 1 L1 models ...
# (_dystack pid=19824) Fitting model: CatBoost_BAG_L1_FULL ...
# (_dystack pid=19824) 	120.71s	 = Training   runtime
# (_dystack pid=19824) Fitting model: ExtraTreesMSE_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=19824) 	2.57s	 = Training   runtime
# (_dystack pid=19824) 	0.94s	 = Validation runtime
# (_dystack pid=19824) Fitting 1 L1 models ...
# (_dystack pid=19824) Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# (_dystack pid=19824) 	Stopping at the best epoch learned earlier - 8.
# (_dystack pid=19824) 	28.41s	 = Training   runtime
# (_dystack pid=19824) Fitting 1 L1 models ...
# (_dystack pid=19824) Fitting model: XGBoost_BAG_L1_FULL ...
# (_dystack pid=19824) 	0.64s	 = Training   runtime
# (_dystack pid=19824) Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=19824) 	Ensemble Weights: {'LightGBM_BAG_L1': 0.545, 'RandomForestMSE_BAG_L1': 0.273, 'XGBoost_BAG_L1': 0.136, 'LightGBMXT_BAG_L1': 0.045}
# (_dystack pid=19824) 	0.23s	 = Training   runtime
# (_dystack pid=19824) Fitting 1 L2 models ...
# (_dystack pid=19824) Fitting model: LightGBMXT_BAG_L2_FULL ...
# (_dystack pid=19824) 	11.02s	 = Training   runtime
# (_dystack pid=19824) Fitting 1 L2 models ...
# (_dystack pid=19824) Fitting model: LightGBM_BAG_L2_FULL ...
# (_dystack pid=19824) 	3.87s	 = Training   runtime
# (_dystack pid=19824) Fitting model: RandomForestMSE_BAG_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=19824) 	67.7s	 = Training   runtime
# (_dystack pid=19824) 	1.32s	 = Validation runtime
# (_dystack pid=19824) Fitting 1 L2 models ...
# (_dystack pid=19824) Fitting model: CatBoost_BAG_L2_FULL ...
# (_dystack pid=19824) 	23.94s	 = Training   runtime
# (_dystack pid=19824) Fitting model: ExtraTreesMSE_BAG_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=19824) 	3.32s	 = Training   runtime
# (_dystack pid=19824) 	0.99s	 = Validation runtime
# (_dystack pid=19824) Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# (_dystack pid=19824) 	Ensemble Weights: {'RandomForestMSE_BAG_L2': 0.76, 'ExtraTreesMSE_BAG_L2': 0.2, 'LightGBM_BAG_L2': 0.04}
# (_dystack pid=19824) 	0.17s	 = Training   runtime
# (_dystack pid=19824) Updated best model to "WeightedEnsemble_L3_FULL" (Previously "WeightedEnsemble_L3"). AutoGluon will default to using "WeightedEnsemble_L3_FULL" for predict() and predict_proba().
# (_dystack pid=19824) Refit complete, total runtime = 216.36s ... Best model: "WeightedEnsemble_L3_FULL"
# (_dystack pid=19824) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240718_004914\ds_sub_fit\sub_fit_ho")
# (_dystack pid=19824) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                           model  score_holdout     score_val          eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L3_FULL  -4.891082e+07 -6.051043e+07  mean_absolute_error        4.405688            NaN  263.245598                 0.007000                     NaN           0.171632            3       True         14
# 1   RandomForestMSE_BAG_L2_FULL  -4.926527e+07 -6.096266e+07  mean_absolute_error        3.905573            NaN  255.890793                 0.211030                1.316885          67.698782            2       True         11
# 2     ExtraTreesMSE_BAG_L2_FULL  -5.080703e+07 -6.374457e+07  mean_absolute_error        3.854095            NaN  191.509948                 0.159552                0.985382           3.317937            2       True         13
# 3          CatBoost_BAG_L2_FULL  -6.229097e+07 -7.906548e+07  mean_absolute_error        3.717544            NaN  212.129435                 0.023001                     NaN          23.937424            2       True         12
# 4      WeightedEnsemble_L2_FULL  -6.503454e+07 -8.032129e+07  mean_absolute_error        3.276549            NaN   36.740507                 0.012001                     NaN           0.232050            2       True          8
# 5          LightGBM_BAG_L1_FULL  -7.311861e+07 -8.902917e+07  mean_absolute_error        1.653428            NaN   11.577337                 1.653428                     NaN          11.577337            1       True          2
# 6   RandomForestMSE_BAG_L1_FULL  -7.878215e+07 -9.440675e+07  mean_absolute_error        0.324422       1.197556   14.189590                 0.324422                1.197556          14.189590            1       True          3
# 7           XGBoost_BAG_L1_FULL  -8.388828e+07 -1.046853e+08  mean_absolute_error        0.105516            NaN    0.637797                 0.105516                     NaN           0.637797            1       True          7
# 8          LightGBM_BAG_L2_FULL  -8.505382e+07 -8.745495e+07  mean_absolute_error        4.028105            NaN  192.057247                 0.333562                     NaN           3.865237            2       True         10
# 9        LightGBMXT_BAG_L2_FULL  -9.260347e+07 -1.073408e+08  mean_absolute_error        4.961543            NaN  199.213216                 1.267000                     NaN          11.021206            2       True          9
# 10       LightGBMXT_BAG_L1_FULL  -9.871225e+07 -1.483280e+08  mean_absolute_error        1.181182            NaN   10.103733                 1.181182                     NaN          10.103733            1       True          1
# 11    ExtraTreesMSE_BAG_L1_FULL  -1.037660e+08 -1.264308e+08  mean_absolute_error        0.200639       0.944267    2.569369                 0.200639                0.944267           2.569369            1       True          5
# 12         CatBoost_BAG_L1_FULL  -1.068767e+08 -1.405281e+08  mean_absolute_error        0.039317            NaN  120.706320                 0.039317                     NaN         120.706320            1       True          4
# 13  NeuralNetFastAI_BAG_L1_FULL  -2.738468e+08 -2.302120e+08  mean_absolute_error        0.190039            NaN   28.407864                 0.190039                     NaN          28.407864            1       True          6
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	1119s	 = DyStack   runtime |	2481s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 2481s
# AutoGluon will save models to "AutogluonModels\ag-20240718_004914"
# Train Data Rows:    60283
# Train Data Columns: 7
# Label Column:       amt
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    15709.64 MB
# 	Train Data (Original)  Memory Usage: 9.14 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 3 | ['TOTAL_POPULATION', '운영점포평균영업기간', '폐업점포평균영업기간']
# 		('int', [])    : 2 | ['admi_cty_no', 'cnt']
# 		('object', []) : 2 | ['card_tpbuz_cd', '상권변동지표구분']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 2 | ['card_tpbuz_cd', '상권변동지표구분']
# 		('float', [])    : 3 | ['TOTAL_POPULATION', '운영점포평균영업기간', '폐업점포평균영업기간']
# 		('int', [])      : 2 | ['admi_cty_no', 'cnt']
# 	0.2s = Fit runtime
# 	7 features in original data used to generate 7 features in processed data.
# 	Train Data (Processed) Memory Usage: 2.42 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.28s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 9 L1 models ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1653.61s of the 2481.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# 	-139635157.0312	 = Validation score   (-mean_absolute_error)
# 	39.08s	 = Training   runtime
# 	128.36s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 1584.04s of the 2411.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# 	-78839935.585	 = Validation score   (-mean_absolute_error)
# 	45.89s	 = Training   runtime
# 	225.01s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 1506.66s of the 2334.08s of remaining time.
# 	-88047474.5365	 = Validation score   (-mean_absolute_error)
# 	16.17s	 = Training   runtime
# 	1.26s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1488.94s of the 2316.37s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.14%)
# 	-111835305.6408	 = Validation score   (-mean_absolute_error)
# 	1195.65s	 = Training   runtime
# 	0.81s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 290.13s of the 1117.55s of remaining time.
# 	-119781437.0331	 = Validation score   (-mean_absolute_error)
# 	2.95s	 = Training   runtime
# 	1.25s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 285.72s of the 1113.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.21%)
# 	-200596324.8929	 = Validation score   (-mean_absolute_error)
# 	102.48s	 = Training   runtime
# 	1.24s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 179.14s of the 1006.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.20%)
# 	-55993517.1358	 = Validation score   (-mean_absolute_error)
# 	145.55s	 = Training   runtime
# 	102.11s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 16.83s of the 844.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.12%)
# 	-251303477.6713	 = Validation score   (-mean_absolute_error)
# 	17.28s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 823.8s of remaining time.
# 	Ensemble Weights: {'XGBoost_BAG_L1': 0.9, 'LightGBM_BAG_L1': 0.1}
# 	-55327853.0408	 = Validation score   (-mean_absolute_error)
# 	0.28s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 823.49s of the 823.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.24%)
# 	-92834344.751	 = Validation score   (-mean_absolute_error)
# 	55.83s	 = Training   runtime
# 	162.36s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 737.02s of the 736.99s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.22%)
# 	-69319407.8048	 = Validation score   (-mean_absolute_error)
# 	36.72s	 = Training   runtime
# 	10.14s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 688.49s of the 688.46s of remaining time.
# 	-48361700.6064	 = Validation score   (-mean_absolute_error)
# 	75.99s	 = Training   runtime
# 	1.1s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 611.25s of the 611.22s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.23%)
# 	-53416644.2553	 = Validation score   (-mean_absolute_error)
# 	491.24s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 117.03s of the 117.0s of remaining time.
# 	-51634327.1871	 = Validation score   (-mean_absolute_error)
# 	3.55s	 = Training   runtime
# 	1.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 112.31s of the 112.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.35%)
# 	-142795728.6101	 = Validation score   (-mean_absolute_error)
# 	90.29s	 = Training   runtime
# 	1.18s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 19.08s of the 19.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.32%)
# 	-56871046.2436	 = Validation score   (-mean_absolute_error)
# 	17.17s	 = Training   runtime
# 	1.33s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -1.62s of remaining time.
# 	Ensemble Weights: {'RandomForestMSE_BAG_L2': 0.72, 'CatBoost_BAG_L2': 0.2, 'ExtraTreesMSE_BAG_L2': 0.08}
# 	-47420277.1468	 = Validation score   (-mean_absolute_error)
# 	0.33s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2483.36s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 16.4 rows/s (7536 batch size)
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models ...
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# 	10.36s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_BAG_L1_FULL ...
# 	11.57s	 = Training   runtime
# Fitting model: RandomForestMSE_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	16.17s	 = Training   runtime
# 	1.26s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_BAG_L1_FULL ...
# 	403.22s	 = Training   runtime
# Fitting model: ExtraTreesMSE_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	2.95s	 = Training   runtime
# 	1.25s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 18.
# 	66.53s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# 	7.38s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# 	12.14s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'XGBoost_BAG_L1': 0.9, 'LightGBM_BAG_L1': 0.1}
# 	0.28s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBMXT_BAG_L2_FULL ...
# 	12.03s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBM_BAG_L2_FULL ...
# 	2.54s	 = Training   runtime
# Fitting model: RandomForestMSE_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	75.99s	 = Training   runtime
# 	1.1s	 = Validation runtime
# Fitting 1 L2 models ...
# Fitting model: CatBoost_BAG_L2_FULL ...
# 	163.19s	 = Training   runtime
# Fitting model: ExtraTreesMSE_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	3.55s	 = Training   runtime
# 	1.01s	 = Validation runtime
# Fitting 1 L2 models ...
# Fitting model: NeuralNetFastAI_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 9.
# 	37.66s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: XGBoost_BAG_L2_FULL ...
# 	1.43s	 = Training   runtime
# Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'RandomForestMSE_BAG_L2': 0.72, 'CatBoost_BAG_L2': 0.2, 'ExtraTreesMSE_BAG_L2': 0.08}
# 	0.33s	 = Training   runtime
# Updated best model to "WeightedEnsemble_L3_FULL" (Previously "WeightedEnsemble_L3"). AutoGluon will default to using "WeightedEnsemble_L3_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 732.98s ... Best model: "WeightedEnsemble_L3_FULL"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240718_004914")
# Predictions:
#  17703     97124256.0
# 48911    299170080.0
# 57528     11945703.0
# 61736    686248768.0
# 6682      26738188.0
#             ...
# 9626     232441808.0
# 45054     57625640.0
# 58211      7925685.5
# 72755     53721108.0
# 61354    202668672.0
# Name: amt, Length: 15071, dtype: float32
# Actual:
#  17703    114796319
# 48911    288372603
# 57528      5733505
# 61736    662327313
# 6682      13193907
#            ...
# 9626     238901478
# 45054     67519280
# 58211      5295340
# 72755     63422940
# 61354    187471551
# Name: amt, Length: 15071, dtype: int64

# %%
y_pred = predictor.predict(test_df.drop(columns=['amt']))
y_pred.head()
# Out:
# 17703     97124256.0
# 48911    299170080.0
# 57528     11945703.0
# 61736    686248768.0
# 6682      26738188.0
# Name: amt, dtype: float32

# %%
predictor.evaluate(test_df, silent=True)
# Out:
# {'mean_absolute_error': -43366071.98455851,
#  'root_mean_squared_error': -349574519.1429192,
#  'mean_squared_error': -1.2220234443400315e+17,
#  'r2': 0.969869974482294,
#  'pearsonr': 0.9858616256137757,
#  'median_absolute_error': -9264870.0}

# %%
predictor.leaderboard(test_df)
# Out:
#                           model    score_test     score_val
# 0   RandomForestMSE_BAG_L2_FULL -4.280318e+07           NaN  \
# 1      WeightedEnsemble_L3_FULL -4.336607e+07           NaN
# 2      WeightedEnsemble_L2_FULL -4.418481e+07           NaN
# 3           XGBoost_BAG_L1_FULL -4.435759e+07           NaN
# 4     ExtraTreesMSE_BAG_L2_FULL -4.563560e+07           NaN
# 5           XGBoost_BAG_L2_FULL -4.572381e+07           NaN
# 6          CatBoost_BAG_L2_FULL -5.498368e+07           NaN
# 7          LightGBM_BAG_L1_FULL -7.357485e+07           NaN
# 8          LightGBM_BAG_L2_FULL -7.386731e+07           NaN
# 9   RandomForestMSE_BAG_L1_FULL -7.639457e+07           NaN
# 10       RandomForestMSE_BAG_L1 -7.639457e+07 -8.804747e+07
# 11       LightGBMXT_BAG_L2_FULL -8.298942e+07           NaN
# 12         CatBoost_BAG_L1_FULL -1.023805e+08           NaN
# 13       LightGBMXT_BAG_L1_FULL -1.039917e+08           NaN
# 14         ExtraTreesMSE_BAG_L1 -1.129137e+08 -1.197814e+08
# 15    ExtraTreesMSE_BAG_L1_FULL -1.129137e+08           NaN
# 16   NeuralNetTorch_BAG_L1_FULL -2.116901e+08           NaN
# 17  NeuralNetFastAI_BAG_L2_FULL -2.391979e+08           NaN
# 18  NeuralNetFastAI_BAG_L1_FULL -2.792082e+08           NaN
# 19          WeightedEnsemble_L3           NaN -4.742028e+07
# 20       RandomForestMSE_BAG_L2           NaN -4.836170e+07
# 21         ExtraTreesMSE_BAG_L2           NaN -5.163433e+07
# 22              CatBoost_BAG_L2           NaN -5.341664e+07
# 23          WeightedEnsemble_L2           NaN -5.532785e+07
# 24               XGBoost_BAG_L1           NaN -5.599352e+07
# 25               XGBoost_BAG_L2           NaN -5.687105e+07
# 26              LightGBM_BAG_L2           NaN -6.931941e+07
# 27              LightGBM_BAG_L1           NaN -7.883994e+07
# 28            LightGBMXT_BAG_L2           NaN -9.283434e+07
# 29              CatBoost_BAG_L1           NaN -1.118353e+08
# 30            LightGBMXT_BAG_L1           NaN -1.396352e+08
# 31       NeuralNetFastAI_BAG_L2           NaN -1.427957e+08
# 32       NeuralNetFastAI_BAG_L1           NaN -2.005963e+08
# 33        NeuralNetTorch_BAG_L1           NaN -2.513035e+08
#
#             eval_metric  pred_time_test  pred_time_val     fit_time
# 0   mean_absolute_error       15.955386            NaN   606.309146  \
# 1   mean_absolute_error       18.283322            NaN   773.375865
# 2   mean_absolute_error        5.037183            NaN    19.227749
# 3   mean_absolute_error        1.795573            NaN     7.376058
# 4   mean_absolute_error       16.131741            NaN   533.866640
# 5   mean_absolute_error       14.336665            NaN   531.752950
# 6   mean_absolute_error       14.041849            NaN   693.512305
# 7   mean_absolute_error        3.228610            NaN    11.570542
# 8   mean_absolute_error       14.306337            NaN   532.856657
# 9   mean_absolute_error        2.901801       1.256900    16.173656
# 10  mean_absolute_error        4.392368       1.256900    16.173656
# 11  mean_absolute_error       16.533826            NaN   542.348598
# 12  mean_absolute_error        0.288863            NaN   403.218212
# 13  mean_absolute_error        2.263638            NaN    10.363926
# 14  mean_absolute_error        2.229877       1.245666     2.946326
# 15  mean_absolute_error        2.779643       1.245666     2.946326
# 16  mean_absolute_error        0.142554            NaN    12.139889
# 17  mean_absolute_error       14.339242            NaN   567.977620
# 18  mean_absolute_error        0.525900            NaN    66.531943
# 19  mean_absolute_error             NaN     462.756471  2136.152347
# 20  mean_absolute_error             NaN     461.548053  1641.036662
# 21  mean_absolute_error             NaN     461.460065  1568.594157
# 22  mean_absolute_error             NaN     460.636819  2056.288787
# 23  mean_absolute_error             NaN     327.112952   191.720960
# 24  mean_absolute_error             NaN     102.105587   145.551735
# 25  mean_absolute_error             NaN     461.771979  1582.220496
# 26  mean_absolute_error             NaN     470.587261  1601.763326
# 27  mean_absolute_error             NaN     225.005365    45.888076
# 28  mean_absolute_error             NaN     622.804135  1620.881404
# 29  mean_absolute_error             NaN       0.805315  1195.645399
# 30  mean_absolute_error             NaN     128.356684    39.084055
# 31  mean_absolute_error             NaN     461.629444  1655.335641
# 32  mean_absolute_error             NaN       1.240534   102.478817
# 33  mean_absolute_error             NaN       0.429676    17.280004
#
#     pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal
# 0                  2.028803                1.102326          75.988594  \
# 1                  0.007513                     NaN           0.328878
# 2                  0.012999                     NaN           0.281149
# 3                  1.795573                     NaN           7.376058
# 4                  2.205158                1.014338           3.546088
# 5                  0.410082                     NaN           1.432399
# 6                  0.115266                     NaN         163.191754
# 7                  3.228610                     NaN          11.570542
# 8                  0.379754                     NaN           2.536105
# 9                  2.901801                1.256900          16.173656
# 10                 4.392368                1.256900          16.173656
# 11                 2.607243                     NaN          12.028046
# 12                 0.288863                     NaN         403.218212
# 13                 2.263638                     NaN          10.363926
# 14                 2.229877                1.245666           2.946326
# 15                 2.779643                1.245666           2.946326
# 16                 0.142554                     NaN          12.139889
# 17                 0.412659                     NaN          37.657068
# 18                 0.525900                     NaN          66.531943
# 19                      NaN                0.002988           0.328878
# 20                      NaN                1.102326          75.988594
# 21                      NaN                1.014338           3.546088
# 22                      NaN                0.191092         491.240719
# 23                      NaN                0.002000           0.281149
# 24                      NaN              102.105587         145.551735
# 25                      NaN                1.326252          17.172427
# 26                      NaN               10.141534          36.715258
# 27                      NaN              225.005365          45.888076
# 28                      NaN              162.358408          55.833336
# 29                      NaN                0.805315        1195.645399
# 30                      NaN              128.356684          39.084055
# 31                      NaN                1.183717          90.287573
# 32                      NaN                1.240534         102.478817
# 33                      NaN                0.429676          17.280004
#
#     stack_level  can_infer  fit_order
# 0             2       True         29
# 1             3       True         34
# 2             2       True         26
# 3             1       True         24
# 4             2       True         31
# 5             2       True         33
# 6             2       True         30
# 7             1       True         19
# 8             2       True         28
# 9             1       True         20
# 10            1       True          3
# 11            2       True         27
# 12            1       True         21
# 13            1       True         18
# 14            1       True          5
# 15            1       True         22
# 16            1       True         25
# 17            2       True         32
# 18            1       True         23
# 19            3      False         17
# 20            2      False         12
# 21            2      False         14
# 22            2      False         13
# 23            2      False          9
# 24            1      False          7
# 25            2      False         16
# 26            2      False         11
# 27            1      False          2
# 28            2      False         10
# 29            1      False          4
# 30            1      False          1
# 31            2      False         15
# 32            1      False          6
# 33            1      False          8

# %%
predictor.feature_importance(test_df)
# Out:
# Computing feature importance via permutation shuffling for 7 features using 5000 rows with 5 shuffle sets...
# 	139.81s	= Expected runtime (27.96s per shuffle set)
# 	97.15s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                     importance        stddev       p_value  n      p99_high
# cnt               5.532284e+08  3.318879e+07  1.546849e-06  5  6.215646e+08  \
# card_tpbuz_cd     2.773914e+08  7.381404e+06  6.011116e-08  5  2.925898e+08
# 운영점포평균영업기간        1.192350e+08  1.757415e+07  5.502861e-05  5  1.554204e+08
# admi_cty_no       9.718936e+07  2.634064e+07  5.886150e-04  5  1.514251e+08
# TOTAL_POPULATION  5.356106e+07  5.842430e+06  1.672245e-05  5  6.559071e+07
# 상권변동지표구분          1.713687e+07  9.803050e+06  8.704948e-03  5  3.732149e+07
# 폐업점포평균영업기간        1.366927e+07  1.023005e+06  3.736592e-06  5  1.577565e+07
#
#                        p99_low
# cnt               4.848923e+08
# card_tpbuz_cd     2.621930e+08
# 운영점포평균영업기간        8.304953e+07
# admi_cty_no       4.295360e+07
# TOTAL_POPULATION  4.153142e+07
# 상권변동지표구분         -3.047743e+06
# 폐업점포평균영업기간        1.156288e+07

# %%
train_df.to_csv('train_df.csv', index=False, header=True, encoding='utf-8-sig')
test_df.to_csv('test_df.csv', index=False, header=True, encoding='utf-8-sig')
merged_df2.to_csv('preprocessed.csv', index=False, header=True, encoding='utf-8-sig')

# %%
merged_df2.to_csv('preprocessed.csv', index=False, encoding='utf-8-sig')

# %%
test_df.head()
# Out:
#                0    1          2     3            4     5     6    7
# 131339  41171570  O04   40339315  2661    2954590.1   NaN   NaN  NaN
# 87724   41390520  F11   20478534  1149   3956811.25   NaN   NaN  NaN
# 124344  41590259  R02   22249760   412  16680024.86   NaN   NaN  NaN
# 101641  41210655  D06  149739193  2171   5812304.96   NaN   NaN  NaN
# 15760   41590530  S05    5660535  1502   3351212.92  78.6  56.7   LL

# %%
# 예측할 데이터
data = {
    "admi_cty_no": [41590590],
    "card_tpbuz_cd": ["D01"],
    "amt": [365433405],  # 예측에서는 사용되지 않음
    "cnt": [906],
    "TOTAL_POPULATION": [7667999.44	],
    "운영점포평균영업기간": [37.7],
    "폐업점포평균영업기간": [33.8],
    "상권변동지표구분": ["LL"]
}
# # 저장된 인코더 로드
# encoder = joblib.load('encoder.pkl')

df_predict = pd.DataFrame(data)
df_predict = TabularDataset(df_predict)

# %%
predictor2 = TabularPredictor.load(r"AutogluonModels\ag-20240715_073451")
y_pred = predictor2.predict(df_predict.drop(columns=['amt']))

# %%
y_pred
# Out:
# 0    339639264.0
# Name: amt, dtype: float32

# %%
df_predict
# Out:
#    admi_cty_no card_tpbuz_cd     amt  cnt  TOTAL_POPULATION  운영점포평균영업기간  \
# 0     41210510           D06  633562   28          13850.98       188.5
#
#    폐업점포평균영업기간 상권변동지표구분
# 0       358.0       HH

# %%
test_df[(test_df['card_tpbuz_cd'] == 'Y03') & (test_df['admi_cty_no'] == 41210510)]['amt'].mean()
# Out:
# 1094938.0909090908

# %%
class AutogluonWrapper:
    def __init__(self, predictor, feature_names):
        self.ag_model = predictor
        self.feature_names = feature_names
    
    def predict_proba(self, X):
        if isinstance(X, pd.Series):
            X = X.values.reshape(1,-1)
        if not isinstance(X, pd.DataFrame):
            X = pd.DataFrame(X, columns=self.feature_names)
        return self.ag_model.predict_proba(X)

# %%
# %load_ext autoreload
# %autoreload 2
# !pip install -qU shap
# Out:
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\da\anaconda3\envs\jh\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\da\anaconda3\envs\jh\lib\site-packages)

# %%
import shap
shap.initjs()
import warnings
warnings.filterwarnings('ignore')
X_train = train_df.drop(columns=['amt'])
baseline = X_train.sample(100)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import shap
#       2 shap.initjs()
#       3 import warnings
#
# ModuleNotFoundError: No module named 'shap'

# %%
ag_wrapper = AutogluonWrapper(predictor, X_train.columns)
explainer = shap.KernelExplainer(ag_wrapper.predict_proba, baseline)
print("Baseline prediction: ", np.mean(ag_wrapper.predict_proba(baseline)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[119], line 2
#       1 ag_wrapper = AutogluonWrapper(predictor, X_train.columns)
# ----> 2 explainer = shap.KernelExplainer(ag_wrapper.predict_proba, baseline)
#       3 print("Baseline prediction: ", np.mean(ag_wrapper.predict_proba(baseline)))
#
# NameError: name 'shap' is not defined

# %%
train_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 train_data
#
# NameError: name 'train_data' is not defined
