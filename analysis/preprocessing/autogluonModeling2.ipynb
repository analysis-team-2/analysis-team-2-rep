# %% [markdown]
# ## 데이터 불러오기

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import dask.dataframe as dd
import vaex
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as spst
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
card_data = '../data/five_city_data/merged_gyeonggi_day.csv'
flowpop_data = '../data/five_city_data/flowpop.csv'
commercial_area_ndc_data = '../data/five_city_data/updated_commerical_area_ndc.csv'
card_sample = '../data/gm_card.csv'

# %%
# card_df = dd.read_csv(card_sample,encoding='utf-8')

# %%
card_df = dd.read_csv(card_data,encoding='utf-8')
flowpop_df = dd.read_csv(flowpop_data,encoding='utf-8')
comm_df = dd.read_csv(commercial_area_ndc_data,encoding='utf-8')

# %% [markdown]
# ## 데이터 전처리

# %% [markdown]
# #### 카드 소비 데이터

# %%
card_df.head()
# Out:
#      ta_ymd  cty_rgn_no  admi_cty_no card_tpbuz_cd card_tpbuz_nm_1  \
# 0  20230101       41210     41210510           D05           소매/유통
# 1  20230101       41210     41210510           D11           소매/유통
# 2  20230101       41210     41210510           D11           소매/유통
# 3  20230101       41210     41210510           F02           생활서비스
# 4  20230101       41210     41210510           F02           생활서비스
#
#   card_tpbuz_nm_2  hour sex  age  day    amt  cnt
# 0           선물/완구     3   M    5    7  57576    2
# 1           종합소매점     3   F    7    7   8523    2
# 2           종합소매점     7   F    7    7   8023    2
# 3           미용서비스     3   M    4    7  28532    2
# 4           미용서비스     4   F    7    7  74074    2

# %%
#card_df = card_df.compute()

# %%
#card_df.dtypes

# %%
flowpop_df.head()
# Out:
#      ETL_M   ADMI_CD  TIME_CD  M_10_CNT  F_10_CNT  M_20_CNT  F_20_CNT  \
# 0  2023-01  41111560        0   2858.84   2353.63   6248.39   4939.41
# 1  2023-01  41111560        1   3491.05   3021.34   7622.91   6183.19
# 2  2023-01  41111560        2   3433.43   3094.93   7369.46   5974.40
# 3  2023-01  41111560        3   3194.88   2955.40   7014.45   5704.24
# 4  2023-01  41111560        4   3003.63   2818.85   6716.24   5370.39
#
#    M_30_CNT  F_30_CNT  M_40_CNT  F_40_CNT  M_50_CNT  F_50_CNT  M_60_CNT  \
# 0   6684.28   4267.07   6304.54   5347.71   7495.55   5583.58   5411.89
# 1   7793.08   5365.17   7591.39   6765.04   9010.54   6842.45   6755.23
# 2   7510.31   5217.52   7282.29   6413.82   8717.53   6483.81   6631.32
# 3   7172.49   5138.34   6906.87   6334.15   8650.77   6395.10   6540.17
# 4   6980.61   4920.87   6908.53   6217.82   8911.40   6465.25   6940.02
#
#    F_60_CNT  M_70_CNT  F_70_CNT
# 0   4223.19   1086.22   1165.65
# 1   5363.00   1369.42   1499.24
# 2   5241.16   1303.01   1483.83
# 3   5316.28   1333.23   1501.99
# 4   5642.58   1519.33   1577.52

# %%
cnt_columns = flowpop_df.loc[:, 'M_10_CNT':'F_70_CNT'].columns

# %%
comm_df.head()
# Out:
#       행정동코드  기준분기  운영점포평균영업기간  폐업점포평균영업기간 상권변동지표구분 상권변동지표구분명
# 0  41111560     1        99.9        46.4       HL      상권축소
# 1  41111566     1        83.5        43.2       LL      다이나믹
# 2  41111571     1        97.9        38.1       HL      상권축소
# 3  41111572     1        92.9        58.5       HH        정체
# 4  41111573     1        93.1        70.1       HH        정체

# %% [markdown]
# ### 사용하지 않는 속성 제거

# %%
#flowpop_df.drop(['')],axis=1, inplace=True)

# %%
# 필요한 컬럼만 선택하여 병합
# merged_df = pd.merge(card_df[['ta_ymd', 'admi_cty_no', 'amt']], 
#                      flowpop_df[['TIME_CD', 'ADMI_CD', 'M_10_CNT', 'F_10_CNT']], 
#                      how='inner', 
#                      left_on=['ta_ymd', 'admi_cty_no'], 
#                      right_on=['TIME_CD', 'ADMI_CD'])

# 두 DataFrame을 날짜와 admi_cd를 기준으로 병합
#merged_df = dd.merge(card_df, flowpop_df, how='inner', left_on=['ta_ymd', 'admi_cty_no'], right_on=['ETL_YMD', 'ADMI_CD'])

# 중복 컬럼 제거
# merged_df.drop(columns=['TIME_CD', 'ADMI_CD'], inplace=True)

# %%
#merged_df.head()

# %% [markdown]
# ## 카드 소비 데이터만 학습

# %% [markdown]
# ### 범주형 데이터 변환

# %%
# enc_classes = {} 
# def encoding_label(x):   # x: 범주형 타입의 컬럼(Series)
#     le = LabelEncoder()
#     le.fit(x)
#     label = le.transform(x)
#     enc_classes[x.name] = le.classes_   # x.name: 컬럼명
#     return label

# %%
# card_df2 = card_df['card_tpbuz_cd'].apply(encoding_label)
# 오늘, 행정동에서, 어떤 업종에 방문한 연령대의 남성이 발생시킨 매출의 평균
grouped_df = card_df.groupby(["ta_ymd", "admi_cty_no", "card_tpbuz_cd", "sex", "age"]).agg({"amt": "mean", "cnt": "sum"}).reset_index()

grouped_df.head(5)
# Out:
#      ta_ymd  admi_cty_no card_tpbuz_cd sex  age      amt  cnt
# 0  20230101     41210510           D05   M    5  57576.0    2
# 1  20230101     41210510           D11   F    7   8273.0    4
# 2  20230101     41210510           F02   F    4  97650.0    2
# 3  20230101     41210510           F02   F    6  25789.0    2
# 4  20230101     41210510           F02   F    7  74074.0    2

# %%
grouped_df = grouped_df.drop(['ta_ymd'],axis=1)

# %%
train_df, test_df = train_test_split(grouped_df, test_size=0.2, random_state=42)

# %%
# train_size = int(len(card_df) * 0.8)
# train_df = card_df[:train_size]
# test_df = card_df[train_size:]

# %%
predictor = TabularPredictor(
    label='amt',  # 예측할 타겟 컬럼 설정
    eval_metric='mean_absolute_error'  # 평가 지표 설정
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20240711_033255"

# %%
predictor.fit(train_data=train_df)

# %%
# 예측 수행
predictions = predictor.predict(test_df)

# %%
predictions.head()
# Out:
# 1018321    3.377258e+05
# 2124564    2.413185e+04
# 2258131    1.342081e+06
# 2011751    2.614102e+05
# 1738195    7.445822e+04
# Name: amt, dtype: float32

# %%
test_df.head()
# Out:
#          admi_cty_no card_tpbuz_cd sex  age           amt  cnt
# 1018321     41210590           S04   F    6  3.442950e+04    4
# 2124564     41210520           Q14   M    2  3.107500e+04    1
# 2258131     41210610           S04   M    7  3.930405e+06   66
# 2011751     41210550           F02   F    7  4.016005e+05   16
# 1738195     41210580           F03   M    4  6.081390e+06    2

# %%
predictor.leaderboard(test_df)
# Out:
#              model     score_test      score_val          eval_metric  \
# 0    ExtraTreesMSE -185856.722470 -185911.330726  mean_absolute_error
# 1  RandomForestMSE -188120.379728 -187931.481231  mean_absolute_error
# 2         LightGBM -190159.331894 -189084.193637  mean_absolute_error
# 3       LightGBMXT -192731.062032 -192396.499009  mean_absolute_error
# 4         CatBoost -216138.837812 -212478.484948  mean_absolute_error
# 5   KNeighborsUnif -415725.153611 -446119.955703  mean_absolute_error
# 6   KNeighborsDist -416299.692563 -446152.890681  mean_absolute_error
#
#    pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  \
# 0        2.764904       0.123686   201.497280                 2.764904
# 1        2.519405       0.124849   262.785172                 2.519405
# 2        3.645283       0.145639    19.794451                 3.645283
# 3       83.806180       3.146824   177.869431                83.806180
# 4        0.667849       0.080087  1044.560808                 0.667849
# 5       16.806362       1.236200    14.697853                16.806362
# 6       15.315404       0.645500     2.131970                15.315404
#
#    pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                0.123686         201.497280            1       True
# 1                0.124849         262.785172            1       True
# 2                0.145639          19.794451            1       True
# 3                3.146824         177.869431            1       True
# 4                0.080087        1044.560808            1       True
# 5                1.236200          14.697853            1       True
# 6                0.645500           2.131970            1       True
#
#    fit_order
# 0          7
# 1          5
# 2          4
# 3          3
# 4          6
# 5          1
# 6          2

# %% [markdown]
# ## 데이터 결합

# %% [markdown]
# ### 월 별 데이터로 통합, 유동인구와 상권변화지표도 통합

# %%
# 해당일, 해당동의 해당 업종의 특정시간에 매출과 매출건수 총액
card_df2 = card_df.groupby(["ta_ymd", "admi_cty_no", "card_tpbuz_cd"]).agg({"amt": "sum", "cnt":"sum"}).reset_index()

# %%
card_df2.head()
# Out:
#      ta_ymd  admi_cty_no card_tpbuz_cd     amt  cnt
# 0  20230101     41210510           D05   57576    2
# 1  20230101     41210510           D11   16546    4
# 2  20230101     41210510           F02  313388   16
# 3  20230101     41210510           Q01   69266    1
# 4  20230101     41210510           Q15   78222    6

# %%
card_df2['ta_ymd'] = card_df2['ta_ymd'].astype(str)

# %%
card_df2['ta_ymd'] = card_df2['ta_ymd'].str.slice(0, 6)

# %%
card_df2.head()
# Out:
#    ta_ymd  admi_cty_no card_tpbuz_cd     amt  cnt
# 0  202301     41210510           D05   57576    2
# 1  202301     41210510           D11   16546    4
# 2  202301     41210510           F02  313388   16
# 3  202301     41210510           Q01   69266    1
# 4  202301     41210510           Q15   78222    6

# %%
# 월별 행정구별, 업종별, amt 및 cnt 평균
grouped_df = card_df2.groupby(["ta_ymd", "admi_cty_no", "card_tpbuz_cd"]).agg({"amt": "sum", "cnt": "sum"}).reset_index()
grouped_df.head()
# Out:
#    ta_ymd  admi_cty_no card_tpbuz_cd       amt  cnt
# 0  202301     41210510           D05    633562   28
# 1  202301     41210510           D11    171040   28
# 2  202301     41210510           F02  12060758  375
# 3  202301     41210510           Q01   1818710    9
# 4  202301     41210510           Q15   2167723   87

# %%
# join을 위한 데이터 통일
flowpop_df['ETL_M'] = flowpop_df['ETL_M'].str.replace('-', '')
# 총 유동인구 계산
cnt_columns = flowpop_df.loc[:, 'M_10_CNT':'F_70_CNT'].columns
flowpop_df['TOTAL_POPULATION'] = flowpop_df[cnt_columns].sum(axis=1)
# 해당 월에 해당 동에 해당 시간에 방문한 유동인구수 평균
flowpop_df_temp = flowpop_df.groupby(["ETL_M", "ADMI_CD","TIME_CD"]).agg({"TOTAL_POPULATION": "mean"}).reset_index()
# 해당 월에 해당 동에 방문한 유동인구 평균 총합
flow_g_df = flowpop_df_temp.groupby(["ETL_M", "ADMI_CD"]).agg({"TOTAL_POPULATION": "sum"}).reset_index()

# %%
flow_g_df.head()
# Out:
#     ETL_M   ADMI_CD  TOTAL_POPULATION
# 0  202301  41111560        2968697.82
# 1  202301  41111566        5438074.73
# 2  202301  41111571        2764829.73
# 3  202301  41111572        3664691.19
# 4  202301  41111573        5278122.27

# %%
# 데이터 결합
merged_df = dd.merge(grouped_df, flow_g_df, how='inner', left_on=['ta_ymd', 'admi_cty_no'], right_on=['ETL_M', 'ADMI_CD'])

# %%
merged_df.head()
# Out:
#    ta_ymd  admi_cty_no card_tpbuz_cd       amt  cnt   ETL_M   ADMI_CD  \
# 0  202301     41210510           D05    633562   28  202301  41210510
# 1  202301     41210510           D11    171040   28  202301  41210510
# 2  202301     41210510           F02  12060758  375  202301  41210510
# 3  202301     41210510           Q01   1818710    9  202301  41210510
# 4  202301     41210510           Q15   2167723   87  202301  41210510
#
#    TOTAL_POPULATION
# 0          13850.98
# 1          13850.98
# 2          13850.98
# 3          13850.98
# 4          13850.98

# %%
# 기준분기 생성 함수
def get_quarter(month):
    if month in [1, 2, 3]:
        return 1
    elif month in [4, 5, 6]:
        return 2
    elif month in [7, 8, 9]:
        return 3
    elif month in [10, 11, 12]:
        return 4

# merged_df에서 기준분기 생성
merged_df['year'] = merged_df['ta_ymd'].astype(str).str[:4].astype(int)
merged_df['month'] = merged_df['ta_ymd'].astype(str).str[4:6].astype(int)
merged_df['기준분기'] = merged_df['month'].apply(get_quarter)

# comm_df에서 기준분기와 매칭될 수 있도록 연도를 추가
comm_df['year'] = 2023
# Out:
# C:\Users\DA\anaconda3\envs\hanati\lib\site-packages\dask\dataframe\core.py:4336: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=('month', 'int64'))
#
#   warnings.warn(meta_warning(meta))

# %%
merged_df.head()
# Out:
#    ta_ymd  admi_cty_no card_tpbuz_cd       amt  cnt   ETL_M   ADMI_CD  \
# 0  202301     41210510           D05    633562   28  202301  41210510
# 1  202301     41210510           D11    171040   28  202301  41210510
# 2  202301     41210510           F02  12060758  375  202301  41210510
# 3  202301     41210510           Q01   1818710    9  202301  41210510
# 4  202301     41210510           Q15   2167723   87  202301  41210510
#
#    TOTAL_POPULATION  year  month  기준분기
# 0          13850.98  2023      1     1
# 1          13850.98  2023      1     1
# 2          13850.98  2023      1     1
# 3          13850.98  2023      1     1
# 4          13850.98  2023      1     1

# %%
comm_df.head()
# Out:
#       행정동코드  기준분기  운영점포평균영업기간  폐업점포평균영업기간 상권변동지표구분 상권변동지표구분명  year
# 0  41111560     1        99.9        46.4       HL      상권축소  2023
# 1  41111566     1        83.5        43.2       LL      다이나믹  2023
# 2  41111571     1        97.9        38.1       HL      상권축소  2023
# 3  41111572     1        92.9        58.5       HH        정체  2023
# 4  41111573     1        93.1        70.1       HH        정체  2023

# %%
# comm_df와 merged_df 병합
merged_result = dd.merge(merged_df, comm_df, left_on=['admi_cty_no', '기준분기', 'year'], right_on=['행정동코드', '기준분기', 'year'], how='left')

# 병합 결과에서 필요없는 열 제거 (예: '행정동코드')
merged_result = merged_result.drop(columns=['행정동코드'])

# 병합 결과 출력
merged_result.head()
# Out:
#    ta_ymd  admi_cty_no card_tpbuz_cd       amt  cnt   ETL_M   ADMI_CD  \
# 0  202301     41210510           D05    633562   28  202301  41210510
# 1  202301     41210510           D11    171040   28  202301  41210510
# 2  202301     41210510           F02  12060758  375  202301  41210510
# 3  202301     41210510           Q01   1818710    9  202301  41210510
# 4  202301     41210510           Q15   2167723   87  202301  41210510
#
#    TOTAL_POPULATION  year  month  기준분기  운영점포평균영업기간  폐업점포평균영업기간 상권변동지표구분  \
# 0          13850.98  2023      1     1       188.5       358.0       HH
# 1          13850.98  2023      1     1       188.5       358.0       HH
# 2          13850.98  2023      1     1       188.5       358.0       HH
# 3          13850.98  2023      1     1       188.5       358.0       HH
# 4          13850.98  2023      1     1       188.5       358.0       HH
#
#   상권변동지표구분명
# 0        정체
# 1        정체
# 2        정체
# 3        정체
# 4        정체

# %%
len(comm_df[comm_df['행정동코드'] == 41210510])
# Out:
# 3

# %%
# 해당 행정동의 상권 지표를 결합
merged_df2 = dd.merge(merged_df, comm_df, how='inner', left_on=['admi_cty_no'], right_on=['행정동코드'])

# %%
#merged_result.isna().sum()

# %%
merged_df2.columns
# Out:
# Index(['ta_ymd', 'admi_cty_no', 'card_tpbuz_cd', 'amt', 'cnt', 'ETL_M',
#        'ADMI_CD', 'TOTAL_POPULATION', 'year_x', 'month', '기준분기_x', '행정동코드',
#        '기준분기_y', '운영점포평균영업기간', '폐업점포평균영업기간', '상권변동지표구분', '상권변동지표구분명',
#        'year_y'],
#       dtype='object')

# %%
# 필요없는 속성 제거
# columns_to_drop = ['ta_ymd','ETL_M', 'ADMI_CD', '행정시명', '행정동명',
#                    '운영점포평균영업기간', '폐업점포평균영업기간', '상권변동지표구분명', 'year','month','기준분기']

# columns_to_drop = ['ta_ymd','ETL_M', 'ADMI_CD', '운영점포평균영업기간', '폐업점포평균영업기간', '상권변동지표구분명', 'year','month','기준분기']
# merged_df2 = merged_df2.drop(columns=columns_to_drop, meta={'ta_ymd': 'int64', 'ETL_M': 'int64', 'ADMI_CD': 'int64', 
#                                                                  '운영점포평균영업기간': 'float64', '폐업점포평균영업기간': 'float64', 
#                                                                  '상권변동지표구분명': 'object', 'year': 'int64', 'month': 'int64', '기준분기': 'int64'})


columns_to_drop = ['ta_ymd','ETL_M', 'ADMI_CD', 'year_x','기준분기_x', '행정동코드','기준분기_y',
                   '상권변동지표구분명', 'year_y','month']
merged_df2 = merged_df2.drop(columns=columns_to_drop)

# %%
merged_df2.head()
# Out:
#    admi_cty_no card_tpbuz_cd     amt  cnt  TOTAL_POPULATION  운영점포평균영업기간  \
# 0     41210510           D05  633562   28          13850.98       188.5
# 1     41210510           D05  633562   28          13850.98       188.5
# 2     41210510           D05  633562   28          13850.98       188.5
# 3     41210510           D11  171040   28          13850.98       188.5
# 4     41210510           D11  171040   28          13850.98       188.5
#
#    폐업점포평균영업기간 상권변동지표구분
# 0       358.0       HH
# 1       358.0       HH
# 2       358.0       HH
# 3       358.0       HH
# 4       358.0       HH

# %%
# 505027 rows
len(merged_df2)
# Out:
# 403080

# %% [markdown]
# ## One hot encoding, train-test split

# %%
from multiprocessing import Pool, cpu_count
cpu_count()
# Out:
# 12

# %% [markdown]
# #### 인코딩 없음

# %%
merged_df2 = merged_df2.compute()
# merged_df2_encoded = pd.get_dummies(merged_df2, columns=['card_tpbuz_cd', '상권변동지표구분'])

# # 변환된 DataFrame 확인
# print(merged_df2_encoded.head())

# # train/test 데이터 나누기 (80-20 비율)
# train_df, test_df = train_test_split(merged_df2_encoded, test_size=0.2, random_state=42)

# %%
train_df, test_df = train_test_split(merged_df2, test_size=0.2, random_state=42)

# %% [markdown]
# ## 모델 학습1

# %%
# Autogluon TabularPredictor 사용
predictor = TabularPredictor(
    label='amt',  # 예측할 타겟 컬럼 설정
    eval_metric='mean_absolute_error'  # 평가 지표 설정 
)

# 모델 훈련
predictor.fit(
    train_data=train_df,
    presets='good_quality_faster_inference_only_refit',  # 가벼운 모델 설정
    time_limit=7200  # 학습 시간 2시간으로 제한 (7200초)
)

# 예측 수행
predictions = predictor.predict(test_df)

# 예측 결과 및 실제 값 비교
print("Predictions:\n", predictions)
print("Actual:\n", test_df['amt'])
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20240713_155155"
# Preset alias specified: 'good_quality_faster_inference_only_refit' maps to 'good_quality'.
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.8.18
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          12
# Memory Avail:       16.02 GB / 31.69 GB (50.6%)
# Disk Space Avail:   555.74 GB / 930.86 GB (59.7%)
# ===================================================
# Presets specified: ['good_quality_faster_inference_only_refit']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Note: `save_bag_folds=False`! This will greatly reduce peak disk usage during fit (by ~8x), but runs the risk of an out-of-memory error during model refit if memory is small relative to the data size.
# 	You can avoid this risk by setting `save_bag_folds=True`.
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 1800s of the 7200s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-07-14 00:52:02,114	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8266
# 		Context path: "AutogluonModels\ag-20240713_155155\ds_sub_fit\sub_fit_ho"
# (_dystack pid=28352) Running DyStack sub-fit ...
# (_dystack pid=28352) Beginning AutoGluon training ... Time limit = 1791s
# (_dystack pid=28352) AutoGluon will save models to "AutogluonModels\ag-20240713_155155\ds_sub_fit\sub_fit_ho"
# (_dystack pid=28352) Train Data Rows:    286634
# (_dystack pid=28352) Train Data Columns: 7
# (_dystack pid=28352) Label Column:       amt
# (_dystack pid=28352) Problem Type:       regression
# (_dystack pid=28352) Preprocessing data ...
# (_dystack pid=28352) Using Feature Generators to preprocess the data ...
# (_dystack pid=28352) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=28352) 	Available Memory:                    15807.08 MB
# (_dystack pid=28352) 	Train Data (Original)  Memory Usage: 43.46 MB (0.3% of available memory)
# (_dystack pid=28352) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=28352) 	Stage 1 Generators:
# (_dystack pid=28352) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=28352) 	Stage 2 Generators:
# (_dystack pid=28352) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=28352) 	Stage 3 Generators:
# (_dystack pid=28352) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=28352) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=28352) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=28352) 	Stage 4 Generators:
# (_dystack pid=28352) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=28352) 	Stage 5 Generators:
# (_dystack pid=28352) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=28352) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=28352) 		('float', [])  : 3 | ['TOTAL_POPULATION', '운영점포평균영업기간', '폐업점포평균영업기간']
# (_dystack pid=28352) 		('int', [])    : 2 | ['admi_cty_no', 'cnt']
# (_dystack pid=28352) 		('object', []) : 2 | ['card_tpbuz_cd', '상권변동지표구분']
# (_dystack pid=28352) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=28352) 		('category', []) : 2 | ['card_tpbuz_cd', '상권변동지표구분']
# (_dystack pid=28352) 		('float', [])    : 3 | ['TOTAL_POPULATION', '운영점포평균영업기간', '폐업점포평균영업기간']
# (_dystack pid=28352) 		('int', [])      : 2 | ['admi_cty_no', 'cnt']
# (_dystack pid=28352) 	0.6s = Fit runtime
# (_dystack pid=28352) 	7 features in original data used to generate 7 features in processed data.
# (_dystack pid=28352) 	Train Data (Processed) Memory Usage: 11.48 MB (0.1% of available memory)
# (_dystack pid=28352) Data preprocessing and feature engineering runtime = 0.69s ...
# (_dystack pid=28352) AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# (_dystack pid=28352) 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# (_dystack pid=28352) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=28352) User-specified model hyperparameters to be fit:
# (_dystack pid=28352) {
# (_dystack pid=28352) 	'NN_TORCH': {},
# (_dystack pid=28352) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=28352) 	'CAT': {},
# (_dystack pid=28352) 	'XGB': {},
# (_dystack pid=28352) 	'FASTAI': {},
# (_dystack pid=28352) 	'RF': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=28352) 	'XT': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=28352) }
# (_dystack pid=28352) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=28352) Fitting 9 L1 models ...
# (_dystack pid=28352) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1192.96s of the 1789.89s of remaining time.
# (_dystack pid=28352) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.58%)
# (_ray_fit pid=24764) [1000]	valid_set's l1: 9.49335e+07
# (_ray_fit pid=24764) [2000]	valid_set's l1: 8.06295e+07 [repeated 8x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=24784) [3000]	valid_set's l1: 7.91135e+07 [repeated 8x across cluster]
# (_ray_fit pid=24784) [4000]	valid_set's l1: 7.31219e+07 [repeated 8x across cluster]
# (_ray_fit pid=24784) [5000]	valid_set's l1: 6.90719e+07 [repeated 8x across cluster]
# (_ray_fit pid=24784) [6000]	valid_set's l1: 6.60788e+07 [repeated 8x across cluster]
# (_ray_fit pid=24784) [7000]	valid_set's l1: 6.36708e+07 [repeated 8x across cluster]
# (_ray_fit pid=24784) [8000]	valid_set's l1: 6.17974e+07 [repeated 8x across cluster]
# (_ray_fit pid=24784) [9000]	valid_set's l1: 6.02317e+07 [repeated 8x across cluster]
# (_ray_fit pid=24784) [10000]	valid_set's l1: 5.9003e+07 [repeated 8x across cluster]
# (_dystack pid=28352) 	-58148483.1103	 = Validation score   (-mean_absolute_error)
# (_dystack pid=28352) 	155.31s	 = Training   runtime
# (_dystack pid=28352) 	1232.58s	 = Validation runtime
# (_dystack pid=28352) Fitting model: LightGBM_BAG_L1 ... Training model for up to 875.05s of the 1471.98s of remaining time.
# (_dystack pid=28352) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.60%)
# (_ray_fit pid=25056) [1000]	valid_set's l1: 5.70295e+07 [repeated 8x across cluster]
# (_ray_fit pid=25056) [2000]	valid_set's l1: 4.86896e+07 [repeated 8x across cluster]
# (_ray_fit pid=25056) [3000]	valid_set's l1: 4.40784e+07 [repeated 8x across cluster]
# (_ray_fit pid=9028) [4000]	valid_set's l1: 3.97883e+07 [repeated 8x across cluster]
# (_ray_fit pid=9028) [5000]	valid_set's l1: 3.79635e+07 [repeated 8x across cluster]
# (_ray_fit pid=27728) [6000]	valid_set's l1: 3.9612e+07 [repeated 8x across cluster]
# (_ray_fit pid=9028) [7000]	valid_set's l1: 3.57506e+07 [repeated 8x across cluster]
# (_ray_fit pid=27728) [8000]	valid_set's l1: 3.775e+07 [repeated 8x across cluster]
# (_ray_fit pid=27728) [9000]	valid_set's l1: 3.69314e+07 [repeated 8x across cluster]
# (_ray_fit pid=27728) [10000]	valid_set's l1: 3.61509e+07 [repeated 8x across cluster]
# (_dystack pid=28352) 	-35409075.1784	 = Validation score   (-mean_absolute_error)
# (_dystack pid=28352) 	131.94s	 = Training   runtime
# (_dystack pid=28352) 	944.45s	 = Validation runtime
# (_dystack pid=28352) Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 623.35s of the 1220.28s of remaining time.
# (_dystack pid=28352) 	-42122143.7762	 = Validation score   (-mean_absolute_error)
# (_dystack pid=28352) 	51.56s	 = Training   runtime
# (_dystack pid=28352) 	6.87s	 = Validation runtime
# (_dystack pid=28352) Fitting model: CatBoost_BAG_L1 ... Training model for up to 564.58s of the 1161.51s of remaining time.
# (_dystack pid=28352) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.59%)
# (_dystack pid=28352) 	-109941145.4893	 = Validation score   (-mean_absolute_error)
# (_dystack pid=28352) 	453.15s	 = Training   runtime
# (_dystack pid=28352) 	0.35s	 = Validation runtime
# (_dystack pid=28352) Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 107.73s of the 704.66s of remaining time.
# (_dystack pid=28352) 	-95951603.4568	 = Validation score   (-mean_absolute_error)
# (_dystack pid=28352) 	19.36s	 = Training   runtime
# (_dystack pid=28352) 	6.15s	 = Validation runtime
# (_dystack pid=28352) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 81.92s of the 678.85s of remaining time.
# (_dystack pid=28352) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.96%)
# (_dystack pid=28352) 	-186133917.921	 = Validation score   (-mean_absolute_error)
# (_dystack pid=28352) 	53.31s	 = Training   runtime
# (_dystack pid=28352) 	2.85s	 = Validation runtime
# (_dystack pid=28352) Fitting model: XGBoost_BAG_L1 ... Training model for up to 24.78s of the 621.7s of remaining time.
# (_dystack pid=28352) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.77%)
# (_dystack pid=28352) 	-128272036.3804	 = Validation score   (-mean_absolute_error)
# (_dystack pid=28352) 	20.29s	 = Training   runtime
# (_dystack pid=28352) 	1.3s	 = Validation runtime
# (_dystack pid=28352) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 0.63s of the 597.55s of remaining time.
# (_dystack pid=28352) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.57%)
# (_dystack pid=28352) 	Time limit exceeded... Skipping NeuralNetTorch_BAG_L1.
# (_dystack pid=28352) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=15620, ip=127.0.0.1)
# (_dystack pid=28352)   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
# (_dystack pid=28352)   File "C:\Users\DA\anaconda3\envs\hanati\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
# (_dystack pid=28352)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=28352)   File "C:\Users\DA\anaconda3\envs\hanati\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
# (_dystack pid=28352)     out = self._fit(**kwargs)
# (_dystack pid=28352)   File "C:\Users\DA\anaconda3\envs\hanati\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 205, in _fit
# (_dystack pid=28352)     raise TimeLimitExceeded
# (_dystack pid=28352) autogluon.core.utils.exceptions.TimeLimitExceeded
# (_dystack pid=28352) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=30240, ip=127.0.0.1)
# (_dystack pid=28352)   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
# (_dystack pid=28352)   File "C:\Users\DA\anaconda3\envs\hanati\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
# (_dystack pid=28352)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=28352)   File "C:\Users\DA\anaconda3\envs\hanati\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
# (_dystack pid=28352)     out = self._fit(**kwargs)
# (_dystack pid=28352)   File "C:\Users\DA\anaconda3\envs\hanati\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 205, in _fit
# (_dystack pid=28352)     raise TimeLimitExceeded
# (_dystack pid=28352) autogluon.core.utils.exceptions.TimeLimitExceeded
# (_dystack pid=28352) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=29168, ip=127.0.0.1)
# (_dystack pid=28352)   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
# (_dystack pid=28352)   File "C:\Users\DA\anaconda3\envs\hanati\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
# (_dystack pid=28352)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=28352)   File "C:\Users\DA\anaconda3\envs\hanati\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
# (_dystack pid=28352)     out = self._fit(**kwargs)
# (_dystack pid=28352)   File "C:\Users\DA\anaconda3\envs\hanati\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 205, in _fit
# (_dystack pid=28352)     raise TimeLimitExceeded
# (_dystack pid=28352) autogluon.core.utils.exceptions.TimeLimitExceeded
# (_dystack pid=28352) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=16468, ip=127.0.0.1)
# (_dystack pid=28352)   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
# (_dystack pid=28352)   File "C:\Users\DA\anaconda3\envs\hanati\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
# (_dystack pid=28352)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=28352)   File "C:\Users\DA\anaconda3\envs\hanati\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
# (_dystack pid=28352)     out = self._fit(**kwargs)
# (_dystack pid=28352)   File "C:\Users\DA\anaconda3\envs\hanati\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 205, in _fit
# (_dystack pid=28352)     raise TimeLimitExceeded
# (_dystack pid=28352) autogluon.core.utils.exceptions.TimeLimitExceeded
# (_dystack pid=28352) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=14436, ip=127.0.0.1)
# (_dystack pid=28352)   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
# (_dystack pid=28352)   File "C:\Users\DA\anaconda3\envs\hanati\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
# (_dystack pid=28352)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=28352)   File "C:\Users\DA\anaconda3\envs\hanati\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
# (_dystack pid=28352)     out = self._fit(**kwargs)
# (_dystack pid=28352)   File "C:\Users\DA\anaconda3\envs\hanati\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 205, in _fit
# (_dystack pid=28352)     raise TimeLimitExceeded
# (_dystack pid=28352) autogluon.core.utils.exceptions.TimeLimitExceeded
# (_dystack pid=28352) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=14900, ip=127.0.0.1)
# (_dystack pid=28352)   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
# (_dystack pid=28352)   File "C:\Users\DA\anaconda3\envs\hanati\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
# (_dystack pid=28352)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=28352)   File "C:\Users\DA\anaconda3\envs\hanati\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
# (_dystack pid=28352)     out = self._fit(**kwargs)
# (_dystack pid=28352)   File "C:\Users\DA\anaconda3\envs\hanati\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 205, in _fit
# (_dystack pid=28352)     raise TimeLimitExceeded
# (_dystack pid=28352) autogluon.core.utils.exceptions.TimeLimitExceeded
# (_dystack pid=28352) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=19836, ip=127.0.0.1)
# (_dystack pid=28352)   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
# (_dystack pid=28352)   File "C:\Users\DA\anaconda3\envs\hanati\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
# (_dystack pid=28352)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=28352)   File "C:\Users\DA\anaconda3\envs\hanati\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
# (_dystack pid=28352)     out = self._fit(**kwargs)
# (_dystack pid=28352)   File "C:\Users\DA\anaconda3\envs\hanati\lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 205, in _fit
# (_dystack pid=28352)     raise TimeLimitExceeded
# (_dystack pid=28352) autogluon.core.utils.exceptions.TimeLimitExceeded
# (_dystack pid=28352) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 584.53s of remaining time.
# (_dystack pid=28352) 	Ensemble Weights: {'LightGBM_BAG_L1': 0.722, 'RandomForestMSE_BAG_L1': 0.278}
# (_dystack pid=28352) 	-33793224.4297	 = Validation score   (-mean_absolute_error)
# (_dystack pid=28352) 	1.2s	 = Training   runtime
# (_dystack pid=28352) 	0.0s	 = Validation runtime
# (_dystack pid=28352) Fitting 9 L2 models ...
# (_dystack pid=28352) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 583.29s of the 583.23s of remaining time.
# (_dystack pid=28352) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.85%)
# (_ray_fit pid=28024) [1000]	valid_set's l1: 5.83796e+07 [repeated 8x across cluster]
# (_ray_fit pid=28024) [2000]	valid_set's l1: 5.26067e+07 [repeated 8x across cluster]
# (_ray_fit pid=13132) [3000]	valid_set's l1: 4.74506e+07 [repeated 8x across cluster]
# (_ray_fit pid=13132) [4000]	valid_set's l1: 4.5731e+07 [repeated 8x across cluster]
# (_ray_fit pid=9304) [4000]	valid_set's l1: 4.9086e+07 [repeated 7x across cluster]
# (_ray_fit pid=13132) [5000]	valid_set's l1: 4.45512e+07
# (_ray_fit pid=25144) [5000]	valid_set's l1: 4.93596e+07
# (_ray_fit pid=9304) [5000]	valid_set's l1: 4.80834e+07 [repeated 6x across cluster]
# (_ray_fit pid=13132) [6000]	valid_set's l1: 4.36229e+07
# (_ray_fit pid=28024) [6000]	valid_set's l1: 4.60191e+07
# (_ray_fit pid=9304) [6000]	valid_set's l1: 4.73015e+07 [repeated 6x across cluster]
# (_ray_fit pid=13132) [7000]	valid_set's l1: 4.29935e+07
# (_ray_fit pid=25144) [7000]	valid_set's l1: 4.75063e+07
# (_ray_fit pid=9304) [7000]	valid_set's l1: 4.66705e+07 [repeated 6x across cluster]
# (_ray_fit pid=13132) [8000]	valid_set's l1: 4.23675e+07
# (_ray_fit pid=25144) [8000]	valid_set's l1: 4.68622e+07
# (_ray_fit pid=9304) [8000]	valid_set's l1: 4.62071e+07 [repeated 6x across cluster]
# (_ray_fit pid=13132) [9000]	valid_set's l1: 4.18864e+07
# (_ray_fit pid=25144) [9000]	valid_set's l1: 4.62455e+07
# (_ray_fit pid=9304) [9000]	valid_set's l1: 4.57987e+07 [repeated 6x across cluster]
# (_ray_fit pid=13132) [10000]	valid_set's l1: 4.14487e+07
# (_ray_fit pid=25144) [10000]	valid_set's l1: 4.57868e+07
# (_ray_fit pid=9304) [10000]	valid_set's l1: 4.54384e+07 [repeated 6x across cluster]
# (_dystack pid=28352) 	-43667630.4675	 = Validation score   (-mean_absolute_error)
# (_dystack pid=28352) 	200.32s	 = Training   runtime
# (_dystack pid=28352) 	1036.72s	 = Validation runtime
# (_dystack pid=28352) Fitting model: LightGBM_BAG_L2 ... Training model for up to 259.02s of the 258.97s of remaining time.
# (_dystack pid=28352) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.84%)
# (_ray_fit pid=24168) [1000]	valid_set's l1: 3.19448e+07
# (_ray_fit pid=27256) [1000]	valid_set's l1: 3.26388e+07
# (_ray_fit pid=30232) [2000]	valid_set's l1: 3.3882e+07 [repeated 7x across cluster]
# (_ray_fit pid=30232) [3000]	valid_set's l1: 3.32694e+07 [repeated 8x across cluster]
# (_ray_fit pid=27256) [4000]	valid_set's l1: 3.016e+07 [repeated 8x across cluster]
# (_ray_fit pid=27256) [5000]	valid_set's l1: 2.97733e+07 [repeated 8x across cluster]
# (_ray_fit pid=27256) [6000]	valid_set's l1: 2.94185e+07 [repeated 8x across cluster]
# (_ray_fit pid=27256) [7000]	valid_set's l1: 2.91277e+07 [repeated 8x across cluster]
# (_ray_fit pid=27256) [8000]	valid_set's l1: 2.88456e+07 [repeated 8x across cluster]
# (_ray_fit pid=27256) [9000]	valid_set's l1: 2.86273e+07 [repeated 8x across cluster]
# (_ray_fit pid=27256) [10000]	valid_set's l1: 2.84153e+07 [repeated 8x across cluster]
# (_dystack pid=28352) 	-29298127.494	 = Validation score   (-mean_absolute_error)
# (_dystack pid=28352) 	161.37s	 = Training   runtime
# (_dystack pid=28352) 	895.96s	 = Validation runtime
# (_dystack pid=28352) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -19.42s of remaining time.
# (_dystack pid=28352) 	Ensemble Weights: {'LightGBM_BAG_L2': 0.8, 'LightGBM_BAG_L1': 0.12, 'RandomForestMSE_BAG_L1': 0.08}
# (_dystack pid=28352) 	-28833550.359	 = Validation score   (-mean_absolute_error)
# (_dystack pid=28352) 	0.9s	 = Training   runtime
# (_dystack pid=28352) 	0.0s	 = Validation runtime
# (_dystack pid=28352) AutoGluon training complete, total runtime = 1811.05s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 11.6 rows/s (35830 batch size)
# (_dystack pid=28352) Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# (_dystack pid=28352) Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# (_dystack pid=28352) 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# (_dystack pid=28352) 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# (_dystack pid=28352) 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# (_dystack pid=28352) Fitting 1 L1 models ...
# (_dystack pid=28352) Fitting model: LightGBMXT_BAG_L1_FULL ...
# (_dystack pid=28352) 	33.93s	 = Training   runtime
# (_dystack pid=28352) Fitting 1 L1 models ...
# (_dystack pid=28352) Fitting model: LightGBM_BAG_L1_FULL ...
# (_dystack pid=28352) 	28.05s	 = Training   runtime
# (_dystack pid=28352) Fitting model: RandomForestMSE_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=28352) 	51.56s	 = Training   runtime
# (_dystack pid=28352) 	6.87s	 = Validation runtime
# (_dystack pid=28352) Fitting 1 L1 models ...
# (_dystack pid=28352) Fitting model: CatBoost_BAG_L1_FULL ...
# (_dystack pid=28352) 	106.85s	 = Training   runtime
# (_dystack pid=28352) Fitting model: ExtraTreesMSE_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=28352) 	19.36s	 = Training   runtime
# (_dystack pid=28352) 	6.15s	 = Validation runtime
# (_dystack pid=28352) Fitting 1 L1 models ...
# (_dystack pid=28352) Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# (_dystack pid=28352) 	Stopping at the best epoch learned earlier - 4.
# (_dystack pid=28352) 	43.12s	 = Training   runtime
# (_dystack pid=28352) Fitting 1 L1 models ...
# (_dystack pid=28352) Fitting model: XGBoost_BAG_L1_FULL ...
# (_dystack pid=28352) 	1.13s	 = Training   runtime
# (_dystack pid=28352) Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=28352) 	Ensemble Weights: {'LightGBM_BAG_L1': 0.722, 'RandomForestMSE_BAG_L1': 0.278}
# (_dystack pid=28352) 	1.2s	 = Training   runtime
# (_dystack pid=28352) Fitting 1 L2 models ...
# (_dystack pid=28352) Fitting model: LightGBMXT_BAG_L2_FULL ...
# (_dystack pid=28352) 	40.43s	 = Training   runtime
# (_dystack pid=28352) Fitting 1 L2 models ...
# (_dystack pid=28352) Fitting model: LightGBM_BAG_L2_FULL ...
# (_dystack pid=28352) 	37.44s	 = Training   runtime
# (_dystack pid=28352) Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# (_dystack pid=28352) 	Ensemble Weights: {'LightGBM_BAG_L2': 0.8, 'LightGBM_BAG_L1': 0.12, 'RandomForestMSE_BAG_L1': 0.08}
# (_dystack pid=28352) 	0.9s	 = Training   runtime
# (_dystack pid=28352) Updated best model to "WeightedEnsemble_L3_FULL" (Previously "WeightedEnsemble_L3"). AutoGluon will default to using "WeightedEnsemble_L3_FULL" for predict() and predict_proba().
# (_dystack pid=28352) Refit complete, total runtime = 296.6s ... Best model: "WeightedEnsemble_L3_FULL"
# (_dystack pid=28352) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240713_155155\ds_sub_fit\sub_fit_ho")
# (_dystack pid=28352) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                           model  score_holdout     score_val          eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L3_FULL  -2.559989e+07 -2.883355e+07  mean_absolute_error       18.143665            NaN  322.345163                 0.006981                     NaN           0.895885            3       True         11
# 1          LightGBM_BAG_L2_FULL  -2.581927e+07 -2.929813e+07  mean_absolute_error       18.136684            NaN  321.449278                 4.853758                     NaN          37.442782            2       True         10
# 2      WeightedEnsemble_L2_FULL  -3.055600e+07 -3.379322e+07  mean_absolute_error        5.486145            NaN   80.816186                 0.013963                     NaN           1.201068            2       True          8
# 3          LightGBM_BAG_L1_FULL  -3.098856e+07 -3.540908e+07  mean_absolute_error        5.004542            NaN   28.054433                 5.004542                     NaN          28.054433            1       True          2
# 4        LightGBMXT_BAG_L2_FULL  -3.889560e+07 -4.366763e+07  mean_absolute_error       19.276896            NaN  324.434588                 5.993969                     NaN          40.428092            2       True          9
# 5   RandomForestMSE_BAG_L1_FULL  -4.142849e+07 -4.212214e+07  mean_absolute_error        0.467641        6.87451   51.560685                 0.467641                 6.87451          51.560685            1       True          3
# 6        LightGBMXT_BAG_L1_FULL  -5.428873e+07 -5.814848e+07  mean_absolute_error        6.860031            NaN   33.928126                 6.860031                     NaN          33.928126            1       True          1
# 7     ExtraTreesMSE_BAG_L1_FULL  -9.355811e+07 -9.595160e+07  mean_absolute_error        0.322820        6.15242   19.360276                 0.322820                 6.15242          19.360276            1       True          5
# 8          CatBoost_BAG_L1_FULL  -1.046678e+08 -1.099411e+08  mean_absolute_error        0.036421            NaN  106.851480                 0.036421                     NaN         106.851480            1       True          4
# 9           XGBoost_BAG_L1_FULL  -1.180077e+08 -1.282720e+08  mean_absolute_error        0.132660            NaN    1.132146                 0.132660                     NaN           1.132146            1       True          7
# 10  NeuralNetFastAI_BAG_L1_FULL  -1.640756e+08 -1.861339e+08  mean_absolute_error        0.458812            NaN   43.119350                 0.458812                     NaN          43.119350            1       True          6
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	2144s	 = DyStack   runtime |	5056s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 5056s
# AutoGluon will save models to "AutogluonModels\ag-20240713_155155"
# Train Data Rows:    322464
# Train Data Columns: 7
# Label Column:       amt
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    16546.24 MB
# 	Train Data (Original)  Memory Usage: 48.90 MB (0.3% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 3 | ['TOTAL_POPULATION', '운영점포평균영업기간', '폐업점포평균영업기간']
# 		('int', [])    : 2 | ['admi_cty_no', 'cnt']
# 		('object', []) : 2 | ['card_tpbuz_cd', '상권변동지표구분']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 2 | ['card_tpbuz_cd', '상권변동지표구분']
# 		('float', [])    : 3 | ['TOTAL_POPULATION', '운영점포평균영업기간', '폐업점포평균영업기간']
# 		('int', [])      : 2 | ['admi_cty_no', 'cnt']
# 	0.6s = Fit runtime
# 	7 features in original data used to generate 7 features in processed data.
# 	Train Data (Processed) Memory Usage: 12.92 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 0.66s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 9 L1 models ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 3369.3s of the 5055.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	-55933593.9924	 = Validation score   (-mean_absolute_error)
# 	182.56s	 = Training   runtime
# 	1356.11s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 3016.34s of the 4702.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	-32803844.863	 = Validation score   (-mean_absolute_error)
# 	149.25s	 = Training   runtime
# 	1051.24s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 2737.62s of the 4423.53s of remaining time.
# 	-39811790.0121	 = Validation score   (-mean_absolute_error)
# 	58.0s	 = Training   runtime
# 	7.64s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2671.53s of the 4357.44s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.64%)
# 	-79421455.8728	 = Validation score   (-mean_absolute_error)
# 	2146.32s	 = Training   runtime
# 	1.73s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 522.77s of the 2208.68s of remaining time.
# 	-93775267.8921	 = Validation score   (-mean_absolute_error)
# 	22.84s	 = Training   runtime
# 	6.56s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 493.11s of the 2179.03s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.10%)
# 	-173093069.4368	 = Validation score   (-mean_absolute_error)
# 	245.27s	 = Training   runtime
# 	2.65s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 245.33s of the 1931.24s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.86%)
# 	-63826287.512	 = Validation score   (-mean_absolute_error)
# 	198.16s	 = Training   runtime
# 	9.81s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 43.59s of the 1729.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.64%)
# 	-143767249.2336	 = Validation score   (-mean_absolute_error)
# 	38.59s	 = Training   runtime
# 	1.45s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 2.38s of the 1688.29s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.74%)
# 	-136355138.2695	 = Validation score   (-mean_absolute_error)
# 	5.21s	 = Training   runtime
# 	1.32s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 1680.12s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L1': 0.739, 'RandomForestMSE_BAG_L1': 0.261}
# 	-31438768.7394	 = Validation score   (-mean_absolute_error)
# 	1.27s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1678.81s of the 1678.77s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.07%)
# 	-41357562.8987	 = Validation score   (-mean_absolute_error)
# 	231.84s	 = Training   runtime
# 	1154.28s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1308.98s of the 1308.94s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.09%)
# 	-29713561.2861	 = Validation score   (-mean_absolute_error)
# 	192.56s	 = Training   runtime
# 	971.03s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 996.25s of the 996.21s of remaining time.
# 	-26258576.5037	 = Validation score   (-mean_absolute_error)
# 	366.52s	 = Training   runtime
# 	7.21s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 622.22s of the 622.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.11%)
# 	-35560909.8472	 = Validation score   (-mean_absolute_error)
# 	499.91s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 119.83s of the 119.79s of remaining time.
# 	-28242684.1904	 = Validation score   (-mean_absolute_error)
# 	42.48s	 = Training   runtime
# 	6.66s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 70.32s of the 70.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.87%)
# 	-139061234.4071	 = Validation score   (-mean_absolute_error)
# 	51.26s	 = Training   runtime
# 	2.96s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 16.31s of the 16.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.47%)
# 	-61607819.051	 = Validation score   (-mean_absolute_error)
# 	15.26s	 = Training   runtime
# 	1.21s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -1.81s of remaining time.
# 	Ensemble Weights: {'RandomForestMSE_BAG_L2': 0.773, 'LightGBM_BAG_L2': 0.182, 'ExtraTreesMSE_BAG_L2': 0.045}
# 	-25888618.8329	 = Validation score   (-mean_absolute_error)
# 	1.64s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 5059.38s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 11.9 rows/s (40308 batch size)
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models ...
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# 	36.15s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_BAG_L1_FULL ...
# 	31.35s	 = Training   runtime
# Fitting model: RandomForestMSE_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	58.0s	 = Training   runtime
# 	7.64s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_BAG_L1_FULL ...
# 	495.62s	 = Training   runtime
# Fitting model: ExtraTreesMSE_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	22.84s	 = Training   runtime
# 	6.56s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 14.
# 	148.08s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# 	3.99s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# 	43.25s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBMLarge_BAG_L1_FULL ...
# 	0.71s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'LightGBM_BAG_L1': 0.739, 'RandomForestMSE_BAG_L1': 0.261}
# 	1.27s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBMXT_BAG_L2_FULL ...
# 	43.74s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBM_BAG_L2_FULL ...
# 	38.65s	 = Training   runtime
# Fitting model: RandomForestMSE_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	366.52s	 = Training   runtime
# 	7.21s	 = Validation runtime
# Fitting 1 L2 models ...
# Fitting model: CatBoost_BAG_L2_FULL ...
# 	108.55s	 = Training   runtime
# Fitting model: ExtraTreesMSE_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	42.48s	 = Training   runtime
# 	6.66s	 = Validation runtime
# Fitting 1 L2 models ...
# Fitting model: NeuralNetFastAI_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 2.
# 	29.58s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: XGBoost_BAG_L2_FULL ...
# 	1.57s	 = Training   runtime
# Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'RandomForestMSE_BAG_L2': 0.773, 'LightGBM_BAG_L2': 0.182, 'ExtraTreesMSE_BAG_L2': 0.045}
# 	1.64s	 = Training   runtime
# Updated best model to "WeightedEnsemble_L3_FULL" (Previously "WeightedEnsemble_L3"). AutoGluon will default to using "WeightedEnsemble_L3_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 988.01s ... Best model: "WeightedEnsemble_L3_FULL"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240713_155155")
# Predictions:
#  388390    3.370092e+08
# 93442     1.859493e+07
# 396598    1.978121e+08
# 166263    1.547492e+08
# 88675     2.195473e+07
#               ...
# 155526    2.085138e+08
# 168829    1.463328e+09
# 153934    3.120311e+08
# 259348    2.919446e+07
# 310736    6.388817e+08
# Name: amt, Length: 80616, dtype: float32
# Actual:
#  388390     365433405
# 93442       15489679
# 396598     193816450
# 166263     204928779
# 88675       23182820
#              ...
# 155526     183013621
# 168829    1543539840
# 153934     362683500
# 259348      29006955
# 310736     613019243
# Name: amt, Length: 80616, dtype: int64

# %%
y_pred = predictor.predict(test_df.drop(columns=['amt']))
y_pred.head()
# Out:
# 388390    337009152.0
# 93442      18594926.0
# 396598    197812112.0
# 166263    154749216.0
# 88675      21954734.0
# Name: amt, dtype: float32

# %%
predictor.evaluate(test_df, silent=True)
# Out:
# {'mean_absolute_error': -23624077.210180342,
#  'root_mean_squared_error': -130458653.75958534,
#  'mean_squared_error': -1.701946034076337e+16,
#  'r2': 0.9945592814404532,
#  'pearsonr': 0.9972770371462285,
#  'median_absolute_error': -7632019.5}

# %%
predictor.leaderboard(test_df)
# Out:
#                           model    score_test     score_val  \
# 0      WeightedEnsemble_L3_FULL -2.362408e+07           NaN
# 1   RandomForestMSE_BAG_L2_FULL -2.412310e+07           NaN
# 2     ExtraTreesMSE_BAG_L2_FULL -2.658757e+07           NaN
# 3          LightGBM_BAG_L2_FULL -2.776437e+07           NaN
# 4      WeightedEnsemble_L2_FULL -2.817289e+07           NaN
# 5          LightGBM_BAG_L1_FULL -2.902978e+07           NaN
# 6   RandomForestMSE_BAG_L1_FULL -3.742274e+07           NaN
# 7        RandomForestMSE_BAG_L1 -3.742274e+07 -3.981179e+07
# 8          CatBoost_BAG_L2_FULL -3.806410e+07           NaN
# 9        LightGBMXT_BAG_L2_FULL -4.117908e+07           NaN
# 10       LightGBMXT_BAG_L1_FULL -5.201863e+07           NaN
# 11          XGBoost_BAG_L2_FULL -5.575277e+07           NaN
# 12          XGBoost_BAG_L1_FULL -6.236742e+07           NaN
# 13         CatBoost_BAG_L1_FULL -7.498041e+07           NaN
# 14    ExtraTreesMSE_BAG_L1_FULL -9.105358e+07           NaN
# 15         ExtraTreesMSE_BAG_L1 -9.105358e+07 -9.377527e+07
# 16   NeuralNetTorch_BAG_L1_FULL -1.226793e+08           NaN
# 17    LightGBMLarge_BAG_L1_FULL -1.298126e+08           NaN
# 18  NeuralNetFastAI_BAG_L1_FULL -2.145188e+08           NaN
# 19  NeuralNetFastAI_BAG_L2_FULL -4.231775e+08           NaN
# 20          WeightedEnsemble_L3           NaN -2.588862e+07
# 21       RandomForestMSE_BAG_L2           NaN -2.625858e+07
# 22         ExtraTreesMSE_BAG_L2           NaN -2.824268e+07
# 23              LightGBM_BAG_L2           NaN -2.971356e+07
# 24          WeightedEnsemble_L2           NaN -3.143877e+07
# 25              LightGBM_BAG_L1           NaN -3.280384e+07
# 26              CatBoost_BAG_L2           NaN -3.556091e+07
# 27            LightGBMXT_BAG_L2           NaN -4.135756e+07
# 28            LightGBMXT_BAG_L1           NaN -5.593359e+07
# 29               XGBoost_BAG_L2           NaN -6.160782e+07
# 30               XGBoost_BAG_L1           NaN -6.382629e+07
# 31              CatBoost_BAG_L1           NaN -7.942146e+07
# 32         LightGBMLarge_BAG_L1           NaN -1.363551e+08
# 33       NeuralNetFastAI_BAG_L2           NaN -1.390612e+08
# 34        NeuralNetTorch_BAG_L1           NaN -1.437672e+08
# 35       NeuralNetFastAI_BAG_L1           NaN -1.730931e+08
#
#             eval_metric  pred_time_test  pred_time_val     fit_time  \
# 0   mean_absolute_error       42.011258            NaN  1289.288063
# 1   mean_absolute_error       30.862741            NaN  1206.522587
# 2   mean_absolute_error       30.781309            NaN   882.482284
# 3   mean_absolute_error       41.183843            NaN   878.658516
# 4   mean_absolute_error       12.234875            NaN    90.632209
# 5   mean_absolute_error       11.624959            NaN    31.354766
# 6   mean_absolute_error        0.596447       7.641167    58.004876
# 7   mean_absolute_error        0.620355       7.641167    58.004876
# 8   mean_absolute_error       30.466165            NaN   948.553739
# 9   mean_absolute_error       43.588910            NaN   883.745816
# 10  mean_absolute_error       15.666633            NaN    36.148825
# 11  mean_absolute_error       30.759527            NaN   841.580018
# 12  mean_absolute_error        0.502273            NaN     3.994922
# 13  mean_absolute_error        0.188523            NaN   495.622173
# 14  mean_absolute_error        0.389528       6.563392    22.835836
# 15  mean_absolute_error        0.411982       6.563392    22.835836
# 16  mean_absolute_error        0.348129            NaN    43.253002
# 17  mean_absolute_error        0.086773            NaN     0.707772
# 18  mean_absolute_error        1.007049            NaN   148.084687
# 19  mean_absolute_error       31.436786            NaN   869.589352
# 20  mean_absolute_error             NaN    3423.423422  3649.397717
# 21  mean_absolute_error             NaN    2445.730347  3412.725004
# 22  mean_absolute_error             NaN    2445.183660  3088.684701
# 23  mean_absolute_error             NaN    3409.551476  3238.768170
# 24  mean_absolute_error             NaN    1058.886121   208.531239
# 25  mean_absolute_error             NaN    1051.239968   149.253797
# 26  mean_absolute_error             NaN    2438.774900  3546.121700
# 27  mean_absolute_error             NaN    3592.803404  3278.045231
# 28  mean_absolute_error             NaN    1356.111057   182.561502
# 29  mean_absolute_error             NaN    2439.735937  3061.466103
# 30  mean_absolute_error             NaN       9.814427   198.158727
# 31  mean_absolute_error             NaN       1.732677  2146.321387
# 32  mean_absolute_error             NaN       1.318722     5.212203
# 33  mean_absolute_error             NaN    2441.482493  3097.467519
# 34  mean_absolute_error             NaN       1.452926    38.586563
# 35  mean_absolute_error             NaN       2.649195   245.274387
#
#     pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  \
# 0                  0.003990                     NaN           1.638397
# 1                  0.452428                7.206817         366.515727
# 2                  0.370997                6.660130          42.475424
# 3                 10.773531                     NaN          38.651655
# 4                  0.013470                     NaN           1.272566
# 5                 11.624959                     NaN          31.354766
# 6                  0.596447                7.641167          58.004876
# 7                  0.620355                7.641167          58.004876
# 8                  0.055852                     NaN         108.546878
# 9                 13.178597                     NaN          43.738956
# 10                15.666633                     NaN          36.148825
# 11                 0.349214                     NaN           1.573158
# 12                 0.502273                     NaN           3.994922
# 13                 0.188523                     NaN         495.622173
# 14                 0.389528                6.563392          22.835836
# 15                 0.411982                6.563392          22.835836
# 16                 0.348129                     NaN          43.253002
# 17                 0.086773                     NaN           0.707772
# 18                 1.007049                     NaN         148.084687
# 19                 1.026473                     NaN          29.582491
# 20                      NaN                0.004998           1.638397
# 21                      NaN                7.206817         366.515727
# 22                      NaN                6.660130          42.475424
# 23                      NaN              971.027946         192.558892
# 24                      NaN                0.004987           1.272566
# 25                      NaN             1051.239968         149.253797
# 26                      NaN                0.251370         499.912423
# 27                      NaN             1154.279874         231.835954
# 28                      NaN             1356.111057         182.561502
# 29                      NaN                1.212407          15.256825
# 30                      NaN                9.814427         198.158727
# 31                      NaN                1.732677        2146.321387
# 32                      NaN                1.318722           5.212203
# 33                      NaN                2.958963          51.258241
# 34                      NaN                1.452926          38.586563
# 35                      NaN                2.649195         245.274387
#
#     stack_level  can_infer  fit_order
# 0             3       True         36
# 1             2       True         31
# 2             2       True         33
# 3             2       True         30
# 4             2       True         28
# 5             1       True         20
# 6             1       True         21
# 7             1       True          3
# 8             2       True         32
# 9             2       True         29
# 10            1       True         19
# 11            2       True         35
# 12            1       True         25
# 13            1       True         22
# 14            1       True         23
# 15            1       True          5
# 16            1       True         26
# 17            1       True         27
# 18            1       True         24
# 19            2       True         34
# 20            3      False         18
# 21            2      False         13
# 22            2      False         15
# 23            2      False         12
# 24            2      False         10
# 25            1      False          2
# 26            2      False         14
# 27            2      False         11
# 28            1      False          1
# 29            2      False         17
# 30            1      False          7
# 31            1      False          4
# 32            1      False          9
# 33            2      False         16
# 34            1      False          8
# 35            1      False          6

# %%
predictor.save('./amt_reg')

# %%
import flask
predictor = TabularPredictor.load(r"AutogluonModels\ag-20240712_120603")

# %%
train_df.head()
train_df.to_csv('train_df.csv', index=False, encoding='utf-8-sig')

# %%
test_df.head()
# Out:
#         admi_cty_no card_tpbuz_cd        amt   cnt  TOTAL_POPULATION  \
# 388390     41590590           D01  365433405   906        7667999.44
# 93442      41113560           D05   15489679   433        5216269.43
# 396598     41590610           Y03  193816450  8579        8766419.48
# 166263     41117580           Q04  204928779  7186        4852703.62
# 88675      41113550           R01   23182820    75        7261073.44
#
#         운영점포평균영업기간  폐업점포평균영업기간 상권변동지표구분
# 388390        37.7        33.8       LL
# 93442         88.4        43.3       HL
# 396598        27.1        28.7       LL
# 166263        71.0        53.0       LL
# 88675         82.7        63.0       LH

# %%
test_df.to_csv('test_df.csv', index=False, encoding='utf-8-sig')

# %%
merged_df2.to_csv('preprocessed.csv', index=False, encoding='utf-8-sig')
